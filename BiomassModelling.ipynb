# %% [markdown]
# <h1>Biomass Extraction and Modeling for Askvoll Region</h1>
#
# This Python code is developed for biomass extraction and modeling in the Askvoll region, utilizing LiDAR data for tree segmentation and extracting tree heights from Digital Surface Model (DSM) and Digital Terrain Model (DTM). The dataset includes precise tree coordinates, and a map of dominant tree species in the Area of Interest (AOI) is incorporated. The workflow involves preprocessing LiDAR data, segmenting trees, calculating heights, identifying species, and estimating biomass. Key libraries such as lidR, geopandas, and scikit-learn are used for LiDAR processing, spatial analysis, and machine learning. The results provide insights into biomass distribution, species composition, and support environmental monitoring in the Askvoll region.

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import img_to_array
from keras.preprocessing import image  # Add this import
import tifffile
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Load tree data from CSV
#tree_data = pd.read_csv('AOI_tree_data.csv')
tree_data = pd.read_csv('newAOI_tree_data11.csv')
# Load and preprocess segmented images
optical_folder = 'Optical_patches_16x16'
sar_folder = 'SAR_patches_16x16'
#labels = tree_data['Biomass'].values
labels = tree_data['Biomass'].values
species_labels = tree_data['TreeSpecies'].values
height_labels = tree_data['Z'].values
DBH_labels = tree_data['DBH'].values

# %%
# Print the shape
print("Shape of tree_data:", tree_data.shape)
# Out:
# Shape of tree_data: (30686, 7)

# %%
#applied Asymptote 
#asymptote_decidious = 20.56964 - 6
#asymptote_pine = 28.67605 - 12
#asymptote_spruce = 36.68428 - 18
asymptote_decidious = 20.56964 
asymptote_pine = 28.67605 
asymptote_spruce = 36.68428 


# Define asymptote values
#asymptote_deciduous = 20.56964 - 4
#asymptote_pine = 28.67605 - 4
#asymptote_spruce = 36.68428 - 4

# Define conditions for filtering
deciduous_condition = (tree_data['TreeSpecies'] == 3) & (tree_data['Z'] > asymptote_decidious)
pine_condition = (tree_data['TreeSpecies'] == 2) & (tree_data['Z'] > asymptote_pine)
spruce_condition = (tree_data['TreeSpecies'] == 1) & (tree_data['Z'] > asymptote_spruce)

# Apply filtering
filtered_tree_data = tree_data[~(deciduous_condition | pine_condition | spruce_condition)]

# Print the filtered DataFrame
print(filtered_tree_data)
tree_data=filtered_tree_data
#labels = tree_data['Biomass'].values
labels = tree_data['Biomass'].values

labels = np.log1p(tree_data['Biomass'])

species_labels = tree_data['TreeSpecies'].values
height_labels = tree_data['Z'].values
DBH_labels = tree_data['DBH'].values
# Out:
#        treeID      Z  TreeSpecies   coords.x1    coords.x2        DBH  \
# 0           1   2.72            0  293752.125  6808799.875   0.000000
# 1           2   6.01            3  293762.625  6808799.875   7.375844
# 2           3   6.28            3  293764.875  6808799.875   7.756884
# 3           4   6.36            3  293786.875  6808799.875   7.871765
# 4           5   6.33            3  293819.875  6808799.875   7.828575
# ...       ...    ...          ...         ...          ...        ...
# 30681   30682   8.14            2  293966.625  6807600.125  11.715224
# 30682   30683   7.28            2  293983.375  6807600.125  10.425126
# 30683   30684  13.38            2  294726.125  6807600.125  21.961304
# 30684   30685  16.09            2  295074.625  6807600.125  30.222160
# 30685   30686  12.59            2  295125.125  6807600.125  20.046341
#
#           Biomass
# 0        0.000000
# 1        9.634474
# 2       10.993850
# 3       11.427600
# 4       11.263212
# ...           ...
# 30681   31.017450
# 30682   22.769565
# 30683  160.113326
# 30684  343.080187
# 30685  127.225109
#
# [29860 rows x 7 columns]

# %%
print(tree_data)
# Out:
#        treeID      Z  TreeSpecies   coords.x1    coords.x2        DBH  \
# 0           1   2.72            0  293752.125  6808799.875   0.000000
# 1           2   6.01            3  293762.625  6808799.875   7.375844
# 2           3   6.28            3  293764.875  6808799.875   7.756884
# 3           4   6.36            3  293786.875  6808799.875   7.871765
# 4           5   6.33            3  293819.875  6808799.875   7.828575
# ...       ...    ...          ...         ...          ...        ...
# 30681   30682   8.14            2  293966.625  6807600.125  11.715224
# 30682   30683   7.28            2  293983.375  6807600.125  10.425126
# 30683   30684  13.38            2  294726.125  6807600.125  21.961304
# 30684   30685  16.09            2  295074.625  6807600.125  30.222160
# 30685   30686  12.59            2  295125.125  6807600.125  20.046341
#
#           Biomass
# 0        0.000000
# 1        9.634474
# 2       10.993850
# 3       11.427600
# 4       11.263212
# ...           ...
# 30681   31.017450
# 30682   22.769565
# 30683  160.113326
# 30684  343.080187
# 30685  127.225109
#
# [29860 rows x 7 columns]

# %%
# Find the index of the row with the maximum 'Biomass'
max_biomass_index = tree_data['Biomass'].idxmax()

# Retrieve the row with the maximum 'Biomass'
max_biomass_row = tree_data.loc[max_biomass_index]

# Print the row with the maximum 'Biomass'
print(max_biomass_row)
# Out:
# treeID         2.674200e+04
# Z              3.647000e+01
# TreeSpecies    1.000000e+00
# coords.x1      2.945561e+05
# coords.x2      6.807863e+06
# DBH            3.584866e+03
# Biomass        1.620708e+04
# Name: 26741, dtype: float64

# %%
# Convert the Series to a DataFrame
max_biomass_row_df = max_biomass_row.to_frame().transpose()

# Print the DataFrame containing only the row with the maximum biomass
print(max_biomass_row_df)
# Out:
#         treeID      Z  TreeSpecies   coords.x1    coords.x2          DBH  \
# 26741  26742.0  36.47          1.0  294556.125  6807863.375  3584.866088
#
#             Biomass
# 26741  16207.076671

# %%
asymptote_decidious
# Out:
# 20.56964

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you've already read the CSV file into 'tree_data'
#tree_data = pd.read_csv('AOI_tree_data.csv')

plt.figure(figsize=(18, 6))

# Scatter plot for Z and DBH
plt.subplot(1, 3, 1)
for species_id in tree_data['TreeSpecies'].unique():
    subset = tree_data[tree_data['TreeSpecies'] == species_id]
    species_name = 'Spruces' if species_id == 1 else ('Pines' if species_id == 2 else 'Deciduous')
    plt.scatter(subset['Z'], subset['DBH'], label=f'{species_name}')

plt.title('Height vs DBH', fontsize=18)
plt.xlabel('Height(m)', fontsize=18)
plt.ylabel('DBH (cm)', fontsize=18)
plt.legend( fontsize=18)

# Scatter plot for Z and Biomass
plt.subplot(1, 3, 2)
for species_id in tree_data['TreeSpecies'].unique():
    subset = tree_data[tree_data['TreeSpecies'] == species_id]
    species_name = 'Spruces' if species_id == 1 else ('Pines' if species_id == 2 else 'Deciduous')
    plt.scatter(subset['Z'], subset['Biomass'], label=f'{species_name}')

plt.title('Height vs Biomass', fontsize=18)
plt.xlabel('Height(m)', fontsize=18)
plt.ylabel('Biomass(KG)', fontsize=18)
plt.legend(fontsize=18)




#plt.figure(figsize=(12, 6))

# Scatter plot for Z and DBH
plt.subplot(1, 3, 3)
for species_id in tree_data['TreeSpecies'].unique():
    subset = tree_data[tree_data['TreeSpecies'] == species_id]
    species_name = 'Spruces' if species_id == 1 else ('Pines' if species_id == 2 else 'Deciduous')
    plt.scatter(subset['DBH'], subset['Biomass'], label=f'{species_name}')

plt.title('DBH vs Biomass', fontsize=18)
plt.xlabel('DBH (cm)', fontsize=18)
plt.ylabel('Biomass (KG)', fontsize=18)
plt.legend( fontsize=18)

plt.savefig('my_plots.png', format='png')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you've already read the CSV file into 'tree_data'
#tree_data = pd.read_csv('AOI_tree_data.csv')

plt.figure(figsize=(12, 6))

# Scatter plot for Z and DBH
plt.subplot(1, 2, 1)
for species_id in tree_data['TreeSpecies'].unique():
    subset = tree_data[tree_data['TreeSpecies'] == species_id]
    species_name = 'Spruces' if species_id == 1 else ('Pines' if species_id == 2 else 'Deciduous')
    plt.scatter(subset['DBH'], subset['Biomass'], label=f'{species_name}')

plt.title('DBH vs Biomass', fontsize=18)
plt.xlabel('DBH (cm)', fontsize=18)
plt.ylabel('Biomass (KG)', fontsize=18)
plt.legend( fontsize=18)

plt.savefig('my_plots.svg', format='svg')

# %%
# Print the minimum and maximum values of 'Biomass'
min_biomass = tree_data['Biomass'].min()
max_biomass = tree_data['Biomass'].max()

print(f"Minimum Biomass: {min_biomass}")
print(f"Maximum Biomass: {max_biomass}")

# Print the minimum and maximum values of 'Biomass'
min_DBH = tree_data['DBH'].min()
max_DBH = tree_data['DBH'].max()

print(f"Minimum DBH: {min_DBH}")
print(f"Maximum DBH: {max_DBH}")

# Print the minimum and maximum values of 'Biomass'
min_Z = tree_data['Z'].min()
max_Z = tree_data['Z'].max()

print(f"Minimum Height: {min_Z}")
print(f"Maximum Height: {max_Z}")


num_rows = tree_data.shape[0]
print(f"Total number of rows: {num_rows}")
# Out:
# Minimum Biomass: 0.0
# Maximum Biomass: 16207.0766707223
# Minimum DBH: 0.0
# Maximum DBH: 93384.1016420012
# Minimum Height: 2.0
# Maximum Height: 36.47
# Total number of rows: 29860

# %%
print(f"Maximum Biomass: {tree_data['Biomass']} ")
# Out:
# Maximum Biomass: 0          0.000000
# 1          9.634474
# 2         10.993850
# 3         11.427600
# 4         11.263212
#             ...
# 30681     31.017450
# 30682     22.769565
# 30683    160.113326
# 30684    343.080187
# 30685    127.225109
# Name: Biomass, Length: 29860, dtype: float64

# %%
biomass_std = tree_data.groupby('TreeSpecies')['Biomass'].std().reset_index()

# Plotting the standard deviation of 'Biomass'
plt.figure(figsize=(12, 6))
plt.bar(biomass_std['TreeSpecies'], biomass_std['Biomass'], color='lightgreen', alpha=0.7)
plt.title('Standard Deviation of Biomass by Tree Species')
plt.xlabel('Tree Species')
plt.ylabel('Standard Deviation')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'tree_data' is already loaded from the CSV

# Group by 'TreeSpecies' and calculate mean and standard deviation for 'Z' and 'Biomass'
grouped_data = tree_data.groupby('TreeSpecies').agg({'Z': ['mean', 'std'], 'Biomass': 'std'}).reset_index()

# Plotting the standard deviation of 'Z' and 'Biomass'
plt.figure(figsize=(12, 6))

# Standard deviation plot for 'Z'
plt.bar(grouped_data['TreeSpecies'], grouped_data[('Z', 'std')], color='lightblue', alpha=0.7, label='Height (Z)')
plt.title('Standard Deviation of Height and Biomass by Tree Species')
plt.xlabel('Tree Species')
plt.ylabel('Standard Deviation')
plt.legend()
plt.show()

# Standard deviation plot for 'Biomass'
plt.bar(grouped_data['TreeSpecies'], grouped_data[('Biomass', 'std')], color='lightgreen', alpha=0.7, label='Biomass')
plt.title('Standard Deviation of Height and Biomass by Tree Species')
plt.xlabel('Tree Species')
plt.ylabel('Standard Deviation')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'tree_data' is already loaded from the CSV

# Group by 'TreeSpecies' and calculate mean and standard deviation for 'Z'
grouped_data = tree_data.groupby('TreeSpecies')['Z'].agg(['mean', 'std']).reset_index()

# Plotting the mean and standard deviation of 'Z'
plt.figure(figsize=(12, 6))
plt.bar(grouped_data['TreeSpecies'], grouped_data['mean'], yerr=grouped_data['std'], capsize=5, color='lightblue', alpha=0.7)
plt.title('Mean and Standard Deviation of Height by Tree Species')
plt.xlabel('Tree Species')
plt.ylabel('Height (m)')
plt.show()

# %%
# Group by 'TreeSpecies' and calculate mean and standard deviation for 'Biomass'
grouped_biomass_data = tree_data.groupby('TreeSpecies')['Biomass'].agg(['mean', 'std']).reset_index()

# Plotting the mean and standard deviation of 'Biomass'
plt.figure(figsize=(12, 6))
plt.bar(grouped_biomass_data['TreeSpecies'], grouped_biomass_data['mean'], yerr=grouped_biomass_data['std'], capsize=5, color='lightgreen', alpha=0.7)
plt.title('Mean and Standard Deviation of Biomass by Tree Species')
plt.xlabel('Tree Species')
plt.ylabel('Biomass (KG)')
plt.show()

# %%
# Create lists for image paths, labels, and species labels
optical_image_paths = []
sar_image_paths = []
#labels = []
#species_labels = []

# %%
# Iterate through tree IDs
for tree_id in tree_data['treeID']:
    # Construct paths for optical and SAR images
    optical_path = os.path.join(optical_folder, f"tree_{tree_id}.0.tif")
    sar_path = os.path.join(sar_folder, f"tree_{tree_id}.0.tif")

    try:
        # Load optical image and extract specific channels (2, 3, and 5)
        optical_image = tifffile.imread(optical_path)[:, :, [2, 3, 5]]
        sar_image= tifffile.imread(sar_path)
        # Print information about the loaded optical image
        print(f"Tree ID: {tree_id}, Optical Image Shape: {optical_image.shape}")
        print(f"Tree ID: {tree_id}, Sar Image Shape: {sar_image.shape}")
        #Display the RGB image
        #plt.imshow(sar_image )
        #plt.title(f'SAR Image: {tree_id} RGB TIFF Image')
        #plt.show()
        
        #plt.imshow(optical_image )
        #plt.title(f'Optical Image: {tree_id} RGB TIFF Image')
        #plt.show()
        #optical_image_paths[tree_id]=optical_image
        #sar_image_paths[tree_id]=sar_image
        
        # Save SAR and optical images to lists
        sar_image_paths.append(sar_image)
        optical_image_paths.append(optical_image)
    except Exception as e:
        print(f"Error loading optical image {optical_path}: {e}")
# Out:
# Tree ID: 1, Optical Image Shape: (16, 16, 3)
# Tree ID: 1, Sar Image Shape: (16, 16)
# Tree ID: 2, Optical Image Shape: (16, 16, 3)
# Tree ID: 2, Sar Image Shape: (16, 16)
# Tree ID: 3, Optical Image Shape: (16, 16, 3)
# Tree ID: 3, Sar Image Shape: (16, 16)
# Tree ID: 4, Optical Image Shape: (16, 16, 3)
# Tree ID: 4, Sar Image Shape: (16, 16)
# Tree ID: 5, Optical Image Shape: (16, 16, 3)
# Tree ID: 5, Sar Image Shape: (16, 16)
# Tree ID: 6, Optical Image Shape: (16, 16, 3)
# Tree ID: 6, Sar Image Shape: (16, 16)
# Tree ID: 7, Optical Image Shape: (16, 16, 3)
# Tree ID: 7, Sar Image Shape: (16, 16)
# Tree ID: 8, Optical Image Shape: (16, 16, 3)
# Tree ID: 8, Sar Image Shape: (16, 16)
# Tree ID: 9, Optical Image Shape: (16, 16, 3)
# Tree ID: 9, Sar Image Shape: (16, 16)
# Tree ID: 10, Optical Image Shape: (16, 16, 3)
# Tree ID: 10, Sar Image Shape: (16, 16)
# Tree ID: 11, Optical Image Shape: (16, 16, 3)
# Tree ID: 11, Sar Image Shape: (16, 16)
# Tree ID: 12, Optical Image Shape: (16, 16, 3)
# Tree ID: 12, Sar Image Shape: (16, 16)
# Tree ID: 13, Optical Image Shape: (16, 16, 3)
# Tree ID: 13, Sar Image Shape: (16, 16)
# Tree ID: 14, Optical Image Shape: (16, 16, 3)
# Tree ID: 14, Sar Image Shape: (16, 16)
# Tree ID: 15, Optical Image Shape: (16, 16, 3)
# Tree ID: 15, Sar Image Shape: (16, 16)
# Tree ID: 16, Optical Image Shape: (16, 16, 3)
# Tree ID: 16, Sar Image Shape: (16, 16)
# Tree ID: 17, Optical Image Shape: (16, 16, 3)
# Tree ID: 17, Sar Image Shape: (16, 16)
# Tree ID: 18, Optical Image Shape: (16, 16, 3)
# Tree ID: 18, Sar Image Shape: (16, 16)
# Tree ID: 19, Optical Image Shape: (16, 16, 3)
# Tree ID: 19, Sar Image Shape: (16, 16)
# Tree ID: 20, Optical Image Shape: (16, 16, 3)
# Tree ID: 20, Sar Image Shape: (16, 16)
# Tree ID: 21, Optical Image Shape: (16, 16, 3)
# Tree ID: 21, Sar Image Shape: (16, 16)
# Tree ID: 22, Optical Image Shape: (16, 16, 3)
# Tree ID: 22, Sar Image Shape: (16, 16)
# Tree ID: 23, Optical Image Shape: (16, 16, 3)
# Tree ID: 23, Sar Image Shape: (16, 16)
# Tree ID: 24, Optical Image Shape: (16, 16, 3)
# Tree ID: 24, Sar Image Shape: (16, 16)
# Tree ID: 25, Optical Image Shape: (16, 16, 3)
# Tree ID: 25, Sar Image Shape: (16, 16)
# Tree ID: 26, Optical Image Shape: (16, 16, 3)
# Tree ID: 26, Sar Image Shape: (16, 16)
# Tree ID: 27, Optical Image Shape: (16, 16, 3)
# Tree ID: 27, Sar Image Shape: (16, 16)
# Tree ID: 28, Optical Image Shape: (16, 16, 3)
# Tree ID: 28, Sar Image Shape: (16, 16)
# Tree ID: 29, Optical Image Shape: (16, 16, 3)
# Tree ID: 29, Sar Image Shape: (16, 16)
# Tree ID: 30, Optical Image Shape: (16, 16, 3)
# Tree ID: 30, Sar Image Shape: (16, 16)
# Tree ID: 31, Optical Image Shape: (16, 16, 3)
# Tree ID: 31, Sar Image Shape: (16, 16)
# Tree ID: 32, Optical Image Shape: (16, 16, 3)
# Tree ID: 32, Sar Image Shape: (16, 16)
# Tree ID: 34, Optical Image Shape: (16, 16, 3)
# Tree ID: 34, Sar Image Shape: (16, 16)
# Tree ID: 35, Optical Image Shape: (16, 16, 3)
# Tree ID: 35, Sar Image Shape: (16, 16)
# Tree ID: 36, Optical Image Shape: (16, 16, 3)
# Tree ID: 36, Sar Image Shape: (16, 16)
# Tree ID: 37, Optical Image Shape: (16, 16, 3)
# Tree ID: 37, Sar Image Shape: (16, 16)
# Tree ID: 38, Optical Image Shape: (16, 16, 3)
# Tree ID: 38, Sar Image Shape: (16, 16)
# Tree ID: 39, Optical Image Shape: (16, 16, 3)
# Tree ID: 39, Sar Image Shape: (16, 16)
# Tree ID: 40, Optical Image Shape: (16, 16, 3)
# Tree ID: 40, Sar Image Shape: (16, 16)
# Tree ID: 41, Optical Image Shape: (16, 16, 3)
# Tree ID: 41, Sar Image Shape: (16, 16)
# Tree ID: 42, Optical Image Shape: (16, 16, 3)
# Tree ID: 42, Sar Image Shape: (16, 16)
# Tree ID: 43, Optical Image Shape: (16, 16, 3)
# Tree ID: 43, Sar Image Shape: (16, 16)
# Tree ID: 44, Optical Image Shape: (16, 16, 3)
# Tree ID: 44, Sar Image Shape: (16, 16)
# Tree ID: 45, Optical Image Shape: (16, 16, 3)
# Tree ID: 45, Sar Image Shape: (16, 16)
# Tree ID: 46, Optical Image Shape: (16, 16, 3)
# Tree ID: 46, Sar Image Shape: (16, 16)
# Tree ID: 47, Optical Image Shape: (16, 16, 3)
# Tree ID: 47, Sar Image Shape: (16, 16)
# Tree ID: 48, Optical Image Shape: (16, 16, 3)
# Tree ID: 48, Sar Image Shape: (16, 16)
# Tree ID: 49, Optical Image Shape: (16, 16, 3)
# Tree ID: 49, Sar Image Shape: (16, 16)
# Tree ID: 50, Optical Image Shape: (16, 16, 3)
# Tree ID: 50, Sar Image Shape: (16, 16)
# Tree ID: 51, Optical Image Shape: (16, 16, 3)
# Tree ID: 51, Sar Image Shape: (16, 16)
# Tree ID: 52, Optical Image Shape: (16, 16, 3)
# Tree ID: 52, Sar Image Shape: (16, 16)
# Tree ID: 53, Optical Image Shape: (16, 16, 3)
# Tree ID: 53, Sar Image Shape: (16, 16)
# Tree ID: 54, Optical Image Shape: (16, 16, 3)
# Tree ID: 54, Sar Image Shape: (16, 16)
# Tree ID: 55, Optical Image Shape: (16, 16, 3)
# Tree ID: 55, Sar Image Shape: (16, 16)
# Tree ID: 56, Optical Image Shape: (16, 16, 3)
# Tree ID: 56, Sar Image Shape: (16, 16)
# Tree ID: 57, Optical Image Shape: (16, 16, 3)
# Tree ID: 57, Sar Image Shape: (16, 16)
# Tree ID: 58, Optical Image Shape: (16, 16, 3)
# Tree ID: 58, Sar Image Shape: (16, 16)
# Tree ID: 59, Optical Image Shape: (16, 16, 3)
# Tree ID: 59, Sar Image Shape: (16, 16)
# Tree ID: 60, Optical Image Shape: (16, 16, 3)
# Tree ID: 60, Sar Image Shape: (16, 16)
# Tree ID: 61, Optical Image Shape: (16, 16, 3)
# Tree ID: 61, Sar Image Shape: (16, 16)
# Tree ID: 62, Optical Image Shape: (16, 16, 3)
# Tree ID: 62, Sar Image Shape: (16, 16)
# Tree ID: 63, Optical Image Shape: (16, 16, 3)
# Tree ID: 63, Sar Image Shape: (16, 16)
# Tree ID: 64, Optical Image Shape: (16, 16, 3)
# Tree ID: 64, Sar Image Shape: (16, 16)
# Tree ID: 65, Optical Image Shape: (16, 16, 3)
# Tree ID: 65, Sar Image Shape: (16, 16)
# Tree ID: 66, Optical Image Shape: (16, 16, 3)
# Tree ID: 66, Sar Image Shape: (16, 16)
# Tree ID: 67, Optical Image Shape: (16, 16, 3)
# Tree ID: 67, Sar Image Shape: (16, 16)
# Tree ID: 68, Optical Image Shape: (16, 16, 3)
# Tree ID: 68, Sar Image Shape: (16, 16)
# Tree ID: 69, Optical Image Shape: (16, 16, 3)
# Tree ID: 69, Sar Image Shape: (16, 16)
# Tree ID: 70, Optical Image Shape: (16, 16, 3)
# Tree ID: 70, Sar Image Shape: (16, 16)
# Tree ID: 71, Optical Image Shape: (16, 16, 3)
# Tree ID: 71, Sar Image Shape: (16, 16)
# Tree ID: 72, Optical Image Shape: (16, 16, 3)
# Tree ID: 72, Sar Image Shape: (16, 16)
# Tree ID: 73, Optical Image Shape: (16, 16, 3)
# Tree ID: 73, Sar Image Shape: (16, 16)
# Tree ID: 74, Optical Image Shape: (16, 16, 3)
# Tree ID: 74, Sar Image Shape: (16, 16)
# Tree ID: 75, Optical Image Shape: (16, 16, 3)
# Tree ID: 75, Sar Image Shape: (16, 16)
# Tree ID: 76, Optical Image Shape: (16, 16, 3)
# Tree ID: 76, Sar Image Shape: (16, 16)
# Tree ID: 77, Optical Image Shape: (16, 16, 3)
# Tree ID: 77, Sar Image Shape: (16, 16)
# Tree ID: 78, Optical Image Shape: (16, 16, 3)
# Tree ID: 78, Sar Image Shape: (16, 16)
# Tree ID: 79, Optical Image Shape: (16, 16, 3)
# Tree ID: 79, Sar Image Shape: (16, 16)
# Tree ID: 80, Optical Image Shape: (16, 16, 3)
# Tree ID: 80, Sar Image Shape: (16, 16)
# Tree ID: 81, Optical Image Shape: (16, 16, 3)
# Tree ID: 81, Sar Image Shape: (16, 16)
# Tree ID: 82, Optical Image Shape: (16, 16, 3)
# Tree ID: 82, Sar Image Shape: (16, 16)
# Tree ID: 83, Optical Image Shape: (16, 16, 3)
# Tree ID: 83, Sar Image Shape: (16, 16)
# Tree ID: 84, Optical Image Shape: (16, 16, 3)
# Tree ID: 84, Sar Image Shape: (16, 16)
# Tree ID: 85, Optical Image Shape: (16, 16, 3)
# Tree ID: 85, Sar Image Shape: (16, 16)
# Tree ID: 86, Optical Image Shape: (16, 16, 3)
# Tree ID: 86, Sar Image Shape: (16, 16)
# Tree ID: 87, Optical Image Shape: (16, 16, 3)
# Tree ID: 87, Sar Image Shape: (16, 16)
# Tree ID: 88, Optical Image Shape: (16, 16, 3)
# Tree ID: 88, Sar Image Shape: (16, 16)
# Tree ID: 89, Optical Image Shape: (16, 16, 3)
# Tree ID: 89, Sar Image Shape: (16, 16)
# Tree ID: 90, Optical Image Shape: (16, 16, 3)
# Tree ID: 90, Sar Image Shape: (16, 16)
# Tree ID: 91, Optical Image Shape: (16, 16, 3)
# Tree ID: 91, Sar Image Shape: (16, 16)
# Tree ID: 92, Optical Image Shape: (16, 16, 3)
# Tree ID: 92, Sar Image Shape: (16, 16)
# Tree ID: 93, Optical Image Shape: (16, 16, 3)
# Tree ID: 93, Sar Image Shape: (16, 16)
# Tree ID: 94, Optical Image Shape: (16, 16, 3)
# Tree ID: 94, Sar Image Shape: (16, 16)
# Tree ID: 95, Optical Image Shape: (16, 16, 3)
# Tree ID: 95, Sar Image Shape: (16, 16)
# Tree ID: 96, Optical Image Shape: (16, 16, 3)
# Tree ID: 96, Sar Image Shape: (16, 16)
# Tree ID: 97, Optical Image Shape: (16, 16, 3)
# Tree ID: 97, Sar Image Shape: (16, 16)
# Tree ID: 98, Optical Image Shape: (16, 16, 3)
# Tree ID: 98, Sar Image Shape: (16, 16)
# Tree ID: 99, Optical Image Shape: (16, 16, 3)
# Tree ID: 99, Sar Image Shape: (16, 16)
# Tree ID: 100, Optical Image Shape: (16, 16, 3)
# Tree ID: 100, Sar Image Shape: (16, 16)
# Tree ID: 101, Optical Image Shape: (16, 16, 3)
# Tree ID: 101, Sar Image Shape: (16, 16)
# Tree ID: 102, Optical Image Shape: (16, 16, 3)
# Tree ID: 102, Sar Image Shape: (16, 16)
# Tree ID: 103, Optical Image Shape: (16, 16, 3)
# Tree ID: 103, Sar Image Shape: (16, 16)
# Tree ID: 104, Optical Image Shape: (16, 16, 3)
# Tree ID: 104, Sar Image Shape: (16, 16)
# Tree ID: 105, Optical Image Shape: (16, 16, 3)
# Tree ID: 105, Sar Image Shape: (16, 16)
# Tree ID: 106, Optical Image Shape: (16, 16, 3)
# Tree ID: 106, Sar Image Shape: (16, 16)
# Tree ID: 107, Optical Image Shape: (16, 16, 3)
# Tree ID: 107, Sar Image Shape: (16, 16)
# Tree ID: 108, Optical Image Shape: (16, 16, 3)
# Tree ID: 108, Sar Image Shape: (16, 16)
# Tree ID: 109, Optical Image Shape: (16, 16, 3)
# Tree ID: 109, Sar Image Shape: (16, 16)
# Tree ID: 110, Optical Image Shape: (16, 16, 3)
# Tree ID: 110, Sar Image Shape: (16, 16)
# Tree ID: 111, Optical Image Shape: (16, 16, 3)
# Tree ID: 111, Sar Image Shape: (16, 16)
# Tree ID: 112, Optical Image Shape: (16, 16, 3)
# Tree ID: 112, Sar Image Shape: (16, 16)
# Tree ID: 113, Optical Image Shape: (16, 16, 3)
# Tree ID: 113, Sar Image Shape: (16, 16)
# Tree ID: 114, Optical Image Shape: (16, 16, 3)
# Tree ID: 114, Sar Image Shape: (16, 16)
# Tree ID: 115, Optical Image Shape: (16, 16, 3)
# Tree ID: 115, Sar Image Shape: (16, 16)
# Tree ID: 116, Optical Image Shape: (16, 16, 3)
# Tree ID: 116, Sar Image Shape: (16, 16)
# Tree ID: 117, Optical Image Shape: (16, 16, 3)
# Tree ID: 117, Sar Image Shape: (16, 16)
# Tree ID: 118, Optical Image Shape: (16, 16, 3)
# Tree ID: 118, Sar Image Shape: (16, 16)
# Tree ID: 119, Optical Image Shape: (16, 16, 3)
# Tree ID: 119, Sar Image Shape: (16, 16)
# Tree ID: 120, Optical Image Shape: (16, 16, 3)
# Tree ID: 120, Sar Image Shape: (16, 16)
# Tree ID: 121, Optical Image Shape: (16, 16, 3)
# Tree ID: 121, Sar Image Shape: (16, 16)
# Tree ID: 122, Optical Image Shape: (16, 16, 3)
# Tree ID: 122, Sar Image Shape: (16, 16)
# Tree ID: 123, Optical Image Shape: (16, 16, 3)
# Tree ID: 123, Sar Image Shape: (16, 16)
# Tree ID: 124, Optical Image Shape: (16, 16, 3)
# Tree ID: 124, Sar Image Shape: (16, 16)
# Tree ID: 125, Optical Image Shape: (16, 16, 3)
# Tree ID: 125, Sar Image Shape: (16, 16)
# Tree ID: 126, Optical Image Shape: (16, 16, 3)
# Tree ID: 126, Sar Image Shape: (16, 16)
# Tree ID: 127, Optical Image Shape: (16, 16, 3)
# Tree ID: 127, Sar Image Shape: (16, 16)
# Tree ID: 128, Optical Image Shape: (16, 16, 3)
# Tree ID: 128, Sar Image Shape: (16, 16)
# Tree ID: 129, Optical Image Shape: (16, 16, 3)
# Tree ID: 129, Sar Image Shape: (16, 16)
# Tree ID: 130, Optical Image Shape: (16, 16, 3)
# Tree ID: 130, Sar Image Shape: (16, 16)
# Tree ID: 131, Optical Image Shape: (16, 16, 3)
# Tree ID: 131, Sar Image Shape: (16, 16)
# Tree ID: 132, Optical Image Shape: (16, 16, 3)
# Tree ID: 132, Sar Image Shape: (16, 16)
# Tree ID: 133, Optical Image Shape: (16, 16, 3)
# Tree ID: 133, Sar Image Shape: (16, 16)
# Tree ID: 134, Optical Image Shape: (16, 16, 3)
# Tree ID: 134, Sar Image Shape: (16, 16)
# Tree ID: 135, Optical Image Shape: (16, 16, 3)
# Tree ID: 135, Sar Image Shape: (16, 16)
# Tree ID: 136, Optical Image Shape: (16, 16, 3)
# Tree ID: 136, Sar Image Shape: (16, 16)
# Tree ID: 137, Optical Image Shape: (16, 16, 3)
# Tree ID: 137, Sar Image Shape: (16, 16)
# Tree ID: 138, Optical Image Shape: (16, 16, 3)
# Tree ID: 138, Sar Image Shape: (16, 16)
# Tree ID: 139, Optical Image Shape: (16, 16, 3)
# Tree ID: 139, Sar Image Shape: (16, 16)
# Tree ID: 140, Optical Image Shape: (16, 16, 3)
# Tree ID: 140, Sar Image Shape: (16, 16)
# Tree ID: 141, Optical Image Shape: (16, 16, 3)
# Tree ID: 141, Sar Image Shape: (16, 16)
# Tree ID: 142, Optical Image Shape: (16, 16, 3)
# Tree ID: 142, Sar Image Shape: (16, 16)
# Tree ID: 143, Optical Image Shape: (16, 16, 3)
# Tree ID: 143, Sar Image Shape: (16, 16)
# Tree ID: 144, Optical Image Shape: (16, 16, 3)
# Tree ID: 144, Sar Image Shape: (16, 16)
# Tree ID: 145, Optical Image Shape: (16, 16, 3)
# Tree ID: 145, Sar Image Shape: (16, 16)
# Tree ID: 146, Optical Image Shape: (16, 16, 3)
# Tree ID: 146, Sar Image Shape: (16, 16)
# Tree ID: 147, Optical Image Shape: (16, 16, 3)
# Tree ID: 147, Sar Image Shape: (16, 16)
# Tree ID: 148, Optical Image Shape: (16, 16, 3)
# Tree ID: 148, Sar Image Shape: (16, 16)
# Tree ID: 149, Optical Image Shape: (16, 16, 3)
# Tree ID: 149, Sar Image Shape: (16, 16)
# Tree ID: 150, Optical Image Shape: (16, 16, 3)
# Tree ID: 150, Sar Image Shape: (16, 16)
# Tree ID: 151, Optical Image Shape: (16, 16, 3)
# Tree ID: 151, Sar Image Shape: (16, 16)
# Tree ID: 152, Optical Image Shape: (16, 16, 3)
# Tree ID: 152, Sar Image Shape: (16, 16)
# Tree ID: 153, Optical Image Shape: (16, 16, 3)
# Tree ID: 153, Sar Image Shape: (16, 16)
# Tree ID: 154, Optical Image Shape: (16, 16, 3)
# Tree ID: 154, Sar Image Shape: (16, 16)
# Tree ID: 155, Optical Image Shape: (16, 16, 3)
# Tree ID: 155, Sar Image Shape: (16, 16)
# Tree ID: 156, Optical Image Shape: (16, 16, 3)
# Tree ID: 156, Sar Image Shape: (16, 16)
# Tree ID: 157, Optical Image Shape: (16, 16, 3)
# Tree ID: 157, Sar Image Shape: (16, 16)
# Tree ID: 158, Optical Image Shape: (16, 16, 3)
# Tree ID: 158, Sar Image Shape: (16, 16)
# Tree ID: 159, Optical Image Shape: (16, 16, 3)
# Tree ID: 159, Sar Image Shape: (16, 16)
# Tree ID: 160, Optical Image Shape: (16, 16, 3)
# Tree ID: 160, Sar Image Shape: (16, 16)
# Tree ID: 161, Optical Image Shape: (16, 16, 3)
# Tree ID: 161, Sar Image Shape: (16, 16)
# Tree ID: 162, Optical Image Shape: (16, 16, 3)
# Tree ID: 162, Sar Image Shape: (16, 16)
# Tree ID: 163, Optical Image Shape: (16, 16, 3)
# Tree ID: 163, Sar Image Shape: (16, 16)
# Tree ID: 164, Optical Image Shape: (16, 16, 3)
# Tree ID: 164, Sar Image Shape: (16, 16)
# Tree ID: 165, Optical Image Shape: (16, 16, 3)
# Tree ID: 165, Sar Image Shape: (16, 16)
# Tree ID: 166, Optical Image Shape: (16, 16, 3)
# Tree ID: 166, Sar Image Shape: (16, 16)
# Tree ID: 167, Optical Image Shape: (16, 16, 3)
# Tree ID: 167, Sar Image Shape: (16, 16)
# Tree ID: 168, Optical Image Shape: (16, 16, 3)
# Tree ID: 168, Sar Image Shape: (16, 16)
# Tree ID: 169, Optical Image Shape: (16, 16, 3)
# Tree ID: 169, Sar Image Shape: (16, 16)
# Tree ID: 170, Optical Image Shape: (16, 16, 3)
# Tree ID: 170, Sar Image Shape: (16, 16)
# Tree ID: 171, Optical Image Shape: (16, 16, 3)
# Tree ID: 171, Sar Image Shape: (16, 16)
# Tree ID: 172, Optical Image Shape: (16, 16, 3)
# Tree ID: 172, Sar Image Shape: (16, 16)
# Tree ID: 173, Optical Image Shape: (16, 16, 3)
# Tree ID: 173, Sar Image Shape: (16, 16)
# Tree ID: 174, Optical Image Shape: (16, 16, 3)
# Tree ID: 174, Sar Image Shape: (16, 16)
# Tree ID: 175, Optical Image Shape: (16, 16, 3)
# Tree ID: 175, Sar Image Shape: (16, 16)
# Tree ID: 176, Optical Image Shape: (16, 16, 3)
# Tree ID: 176, Sar Image Shape: (16, 16)
# Tree ID: 177, Optical Image Shape: (16, 16, 3)
# Tree ID: 177, Sar Image Shape: (16, 16)
# Tree ID: 178, Optical Image Shape: (16, 16, 3)
# Tree ID: 178, Sar Image Shape: (16, 16)
# Tree ID: 179, Optical Image Shape: (16, 16, 3)
# Tree ID: 179, Sar Image Shape: (16, 16)
# Tree ID: 180, Optical Image Shape: (16, 16, 3)
# Tree ID: 180, Sar Image Shape: (16, 16)
# Tree ID: 181, Optical Image Shape: (16, 16, 3)
# Tree ID: 181, Sar Image Shape: (16, 16)
# Tree ID: 182, Optical Image Shape: (16, 16, 3)
# Tree ID: 182, Sar Image Shape: (16, 16)
# Tree ID: 183, Optical Image Shape: (16, 16, 3)
# Tree ID: 183, Sar Image Shape: (16, 16)
# Tree ID: 184, Optical Image Shape: (16, 16, 3)
# Tree ID: 184, Sar Image Shape: (16, 16)
# Tree ID: 185, Optical Image Shape: (16, 16, 3)
# Tree ID: 185, Sar Image Shape: (16, 16)
# Tree ID: 186, Optical Image Shape: (16, 16, 3)
# Tree ID: 186, Sar Image Shape: (16, 16)
# Tree ID: 187, Optical Image Shape: (16, 16, 3)
# Tree ID: 187, Sar Image Shape: (16, 16)
# Tree ID: 188, Optical Image Shape: (16, 16, 3)
# Tree ID: 188, Sar Image Shape: (16, 16)
# Tree ID: 189, Optical Image Shape: (16, 16, 3)
# Tree ID: 189, Sar Image Shape: (16, 16)
# Tree ID: 190, Optical Image Shape: (16, 16, 3)
# Tree ID: 190, Sar Image Shape: (16, 16)
# Tree ID: 191, Optical Image Shape: (16, 16, 3)
# Tree ID: 191, Sar Image Shape: (16, 16)
# Tree ID: 192, Optical Image Shape: (16, 16, 3)
# Tree ID: 192, Sar Image Shape: (16, 16)
# Tree ID: 193, Optical Image Shape: (16, 16, 3)
# Tree ID: 193, Sar Image Shape: (16, 16)
# Tree ID: 194, Optical Image Shape: (16, 16, 3)
# Tree ID: 194, Sar Image Shape: (16, 16)
# Tree ID: 195, Optical Image Shape: (16, 16, 3)
# Tree ID: 195, Sar Image Shape: (16, 16)
# Tree ID: 196, Optical Image Shape: (16, 16, 3)
# Tree ID: 196, Sar Image Shape: (16, 16)
# Tree ID: 197, Optical Image Shape: (16, 16, 3)
# Tree ID: 197, Sar Image Shape: (16, 16)
# Tree ID: 198, Optical Image Shape: (16, 16, 3)
# Tree ID: 198, Sar Image Shape: (16, 16)
# Tree ID: 199, Optical Image Shape: (16, 16, 3)
# Tree ID: 199, Sar Image Shape: (16, 16)
# Tree ID: 200, Optical Image Shape: (16, 16, 3)
# Tree ID: 200, Sar Image Shape: (16, 16)
# Tree ID: 201, Optical Image Shape: (16, 16, 3)
# Tree ID: 201, Sar Image Shape: (16, 16)
# Tree ID: 202, Optical Image Shape: (16, 16, 3)
# Tree ID: 202, Sar Image Shape: (16, 16)
# Tree ID: 203, Optical Image Shape: (16, 16, 3)
# Tree ID: 203, Sar Image Shape: (16, 16)
# Tree ID: 204, Optical Image Shape: (16, 16, 3)
# Tree ID: 204, Sar Image Shape: (16, 16)
# Tree ID: 205, Optical Image Shape: (16, 16, 3)
# Tree ID: 205, Sar Image Shape: (16, 16)
# Tree ID: 206, Optical Image Shape: (16, 16, 3)
# Tree ID: 206, Sar Image Shape: (16, 16)
# Tree ID: 207, Optical Image Shape: (16, 16, 3)
# Tree ID: 207, Sar Image Shape: (16, 16)
# Tree ID: 208, Optical Image Shape: (16, 16, 3)
# Tree ID: 208, Sar Image Shape: (16, 16)
# Tree ID: 209, Optical Image Shape: (16, 16, 3)
# Tree ID: 209, Sar Image Shape: (16, 16)
# Tree ID: 210, Optical Image Shape: (16, 16, 3)
# Tree ID: 210, Sar Image Shape: (16, 16)
# Tree ID: 211, Optical Image Shape: (16, 16, 3)
# Tree ID: 211, Sar Image Shape: (16, 16)
# Tree ID: 212, Optical Image Shape: (16, 16, 3)
# Tree ID: 212, Sar Image Shape: (16, 16)
# Tree ID: 213, Optical Image Shape: (16, 16, 3)
# Tree ID: 213, Sar Image Shape: (16, 16)
# Tree ID: 214, Optical Image Shape: (16, 16, 3)
# Tree ID: 214, Sar Image Shape: (16, 16)
# Tree ID: 215, Optical Image Shape: (16, 16, 3)
# Tree ID: 215, Sar Image Shape: (16, 16)
# Tree ID: 216, Optical Image Shape: (16, 16, 3)
# Tree ID: 216, Sar Image Shape: (16, 16)
# Tree ID: 217, Optical Image Shape: (16, 16, 3)
# Tree ID: 217, Sar Image Shape: (16, 16)
# Tree ID: 218, Optical Image Shape: (16, 16, 3)
# Tree ID: 218, Sar Image Shape: (16, 16)
# Tree ID: 219, Optical Image Shape: (16, 16, 3)
# Tree ID: 219, Sar Image Shape: (16, 16)
# Tree ID: 220, Optical Image Shape: (16, 16, 3)
# Tree ID: 220, Sar Image Shape: (16, 16)
# Tree ID: 221, Optical Image Shape: (16, 16, 3)
# Tree ID: 221, Sar Image Shape: (16, 16)
# Tree ID: 222, Optical Image Shape: (16, 16, 3)
# Tree ID: 222, Sar Image Shape: (16, 16)
# Tree ID: 223, Optical Image Shape: (16, 16, 3)
# Tree ID: 223, Sar Image Shape: (16, 16)
# Tree ID: 224, Optical Image Shape: (16, 16, 3)
# Tree ID: 224, Sar Image Shape: (16, 16)
# Tree ID: 225, Optical Image Shape: (16, 16, 3)
# Tree ID: 225, Sar Image Shape: (16, 16)
# Tree ID: 226, Optical Image Shape: (16, 16, 3)
# Tree ID: 226, Sar Image Shape: (16, 16)
# Tree ID: 227, Optical Image Shape: (16, 16, 3)
# Tree ID: 227, Sar Image Shape: (16, 16)
# Tree ID: 228, Optical Image Shape: (16, 16, 3)
# Tree ID: 228, Sar Image Shape: (16, 16)
# Tree ID: 229, Optical Image Shape: (16, 16, 3)
# Tree ID: 229, Sar Image Shape: (16, 16)
# Tree ID: 230, Optical Image Shape: (16, 16, 3)
# Tree ID: 230, Sar Image Shape: (16, 16)
# Tree ID: 231, Optical Image Shape: (16, 16, 3)
# Tree ID: 231, Sar Image Shape: (16, 16)
# Tree ID: 232, Optical Image Shape: (16, 16, 3)
# Tree ID: 232, Sar Image Shape: (16, 16)
# Tree ID: 233, Optical Image Shape: (16, 16, 3)
# Tree ID: 233, Sar Image Shape: (16, 16)
# Tree ID: 234, Optical Image Shape: (16, 16, 3)
# Tree ID: 234, Sar Image Shape: (16, 16)
# Tree ID: 235, Optical Image Shape: (16, 16, 3)
# Tree ID: 235, Sar Image Shape: (16, 16)
# Tree ID: 236, Optical Image Shape: (16, 16, 3)
# Tree ID: 236, Sar Image Shape: (16, 16)
# Tree ID: 237, Optical Image Shape: (16, 16, 3)
# Tree ID: 237, Sar Image Shape: (16, 16)
# Tree ID: 238, Optical Image Shape: (16, 16, 3)
# Tree ID: 238, Sar Image Shape: (16, 16)
# Tree ID: 239, Optical Image Shape: (16, 16, 3)
# Tree ID: 239, Sar Image Shape: (16, 16)
# Tree ID: 240, Optical Image Shape: (16, 16, 3)
# Tree ID: 240, Sar Image Shape: (16, 16)
# Tree ID: 241, Optical Image Shape: (16, 16, 3)
# Tree ID: 241, Sar Image Shape: (16, 16)
# Tree ID: 242, Optical Image Shape: (16, 16, 3)
# Tree ID: 242, Sar Image Shape: (16, 16)
# Tree ID: 243, Optical Image Shape: (16, 16, 3)
# Tree ID: 243, Sar Image Shape: (16, 16)
# Tree ID: 244, Optical Image Shape: (16, 16, 3)
# Tree ID: 244, Sar Image Shape: (16, 16)
# Tree ID: 245, Optical Image Shape: (16, 16, 3)
# Tree ID: 245, Sar Image Shape: (16, 16)
# Tree ID: 246, Optical Image Shape: (16, 16, 3)
# Tree ID: 246, Sar Image Shape: (16, 16)
# Tree ID: 247, Optical Image Shape: (16, 16, 3)
# Tree ID: 247, Sar Image Shape: (16, 16)
# Tree ID: 248, Optical Image Shape: (16, 16, 3)
# Tree ID: 248, Sar Image Shape: (16, 16)
# Tree ID: 249, Optical Image Shape: (16, 16, 3)
# Tree ID: 249, Sar Image Shape: (16, 16)
# Tree ID: 250, Optical Image Shape: (16, 16, 3)
# Tree ID: 250, Sar Image Shape: (16, 16)
# Tree ID: 251, Optical Image Shape: (16, 16, 3)
# Tree ID: 251, Sar Image Shape: (16, 16)
# Tree ID: 252, Optical Image Shape: (16, 16, 3)
# Tree ID: 252, Sar Image Shape: (16, 16)
# Tree ID: 253, Optical Image Shape: (16, 16, 3)
# Tree ID: 253, Sar Image Shape: (16, 16)
# Tree ID: 254, Optical Image Shape: (16, 16, 3)
# Tree ID: 254, Sar Image Shape: (16, 16)
# Tree ID: 255, Optical Image Shape: (16, 16, 3)
# Tree ID: 255, Sar Image Shape: (16, 16)
# Tree ID: 256, Optical Image Shape: (16, 16, 3)
# Tree ID: 256, Sar Image Shape: (16, 16)
# Tree ID: 257, Optical Image Shape: (16, 16, 3)
# Tree ID: 257, Sar Image Shape: (16, 16)
# Tree ID: 258, Optical Image Shape: (16, 16, 3)
# Tree ID: 258, Sar Image Shape: (16, 16)
# Tree ID: 259, Optical Image Shape: (16, 16, 3)
# Tree ID: 259, Sar Image Shape: (16, 16)
# Tree ID: 260, Optical Image Shape: (16, 16, 3)
# Tree ID: 260, Sar Image Shape: (16, 16)
# Tree ID: 261, Optical Image Shape: (16, 16, 3)
# Tree ID: 261, Sar Image Shape: (16, 16)
# Tree ID: 262, Optical Image Shape: (16, 16, 3)
# Tree ID: 262, Sar Image Shape: (16, 16)
# Tree ID: 263, Optical Image Shape: (16, 16, 3)
# Tree ID: 263, Sar Image Shape: (16, 16)
# Tree ID: 264, Optical Image Shape: (16, 16, 3)
# Tree ID: 264, Sar Image Shape: (16, 16)
# Tree ID: 265, Optical Image Shape: (16, 16, 3)
# Tree ID: 265, Sar Image Shape: (16, 16)
# Tree ID: 266, Optical Image Shape: (16, 16, 3)
# Tree ID: 266, Sar Image Shape: (16, 16)
# Tree ID: 267, Optical Image Shape: (16, 16, 3)
# Tree ID: 267, Sar Image Shape: (16, 16)
# Tree ID: 268, Optical Image Shape: (16, 16, 3)
# Tree ID: 268, Sar Image Shape: (16, 16)
# Tree ID: 269, Optical Image Shape: (16, 16, 3)
# Tree ID: 269, Sar Image Shape: (16, 16)
# Tree ID: 270, Optical Image Shape: (16, 16, 3)
# Tree ID: 270, Sar Image Shape: (16, 16)
# Tree ID: 271, Optical Image Shape: (16, 16, 3)
# Tree ID: 271, Sar Image Shape: (16, 16)
# Tree ID: 272, Optical Image Shape: (16, 16, 3)
# Tree ID: 272, Sar Image Shape: (16, 16)
# Tree ID: 273, Optical Image Shape: (16, 16, 3)
# Tree ID: 273, Sar Image Shape: (16, 16)
# Tree ID: 274, Optical Image Shape: (16, 16, 3)
# Tree ID: 274, Sar Image Shape: (16, 16)
# Tree ID: 275, Optical Image Shape: (16, 16, 3)
# Tree ID: 275, Sar Image Shape: (16, 16)
# Tree ID: 276, Optical Image Shape: (16, 16, 3)
# Tree ID: 276, Sar Image Shape: (16, 16)
# Tree ID: 277, Optical Image Shape: (16, 16, 3)
# Tree ID: 277, Sar Image Shape: (16, 16)
# Tree ID: 278, Optical Image Shape: (16, 16, 3)
# Tree ID: 278, Sar Image Shape: (16, 16)
# Tree ID: 279, Optical Image Shape: (16, 16, 3)
# Tree ID: 279, Sar Image Shape: (16, 16)
# Tree ID: 280, Optical Image Shape: (16, 16, 3)
# Tree ID: 280, Sar Image Shape: (16, 16)
# Tree ID: 281, Optical Image Shape: (16, 16, 3)
# Tree ID: 281, Sar Image Shape: (16, 16)
# Tree ID: 282, Optical Image Shape: (16, 16, 3)
# Tree ID: 282, Sar Image Shape: (16, 16)
# Tree ID: 283, Optical Image Shape: (16, 16, 3)
# Tree ID: 283, Sar Image Shape: (16, 16)
# Tree ID: 284, Optical Image Shape: (16, 16, 3)
# Tree ID: 284, Sar Image Shape: (16, 16)
# Tree ID: 285, Optical Image Shape: (16, 16, 3)
# Tree ID: 285, Sar Image Shape: (16, 16)
# Tree ID: 286, Optical Image Shape: (16, 16, 3)
# Tree ID: 286, Sar Image Shape: (16, 16)
# Tree ID: 287, Optical Image Shape: (16, 16, 3)
# Tree ID: 287, Sar Image Shape: (16, 16)
# Tree ID: 288, Optical Image Shape: (16, 16, 3)
# Tree ID: 288, Sar Image Shape: (16, 16)
# Tree ID: 289, Optical Image Shape: (16, 16, 3)
# Tree ID: 289, Sar Image Shape: (16, 16)
# Tree ID: 290, Optical Image Shape: (16, 16, 3)
# Tree ID: 290, Sar Image Shape: (16, 16)
# Tree ID: 291, Optical Image Shape: (16, 16, 3)
# Tree ID: 291, Sar Image Shape: (16, 16)
# Tree ID: 292, Optical Image Shape: (16, 16, 3)
# Tree ID: 292, Sar Image Shape: (16, 16)
# Tree ID: 293, Optical Image Shape: (16, 16, 3)
# Tree ID: 293, Sar Image Shape: (16, 16)
# Tree ID: 294, Optical Image Shape: (16, 16, 3)
# Tree ID: 294, Sar Image Shape: (16, 16)
# Tree ID: 295, Optical Image Shape: (16, 16, 3)
# Tree ID: 295, Sar Image Shape: (16, 16)
# Tree ID: 296, Optical Image Shape: (16, 16, 3)
# Tree ID: 296, Sar Image Shape: (16, 16)
# Tree ID: 297, Optical Image Shape: (16, 16, 3)
# Tree ID: 297, Sar Image Shape: (16, 16)
# Tree ID: 298, Optical Image Shape: (16, 16, 3)
# Tree ID: 298, Sar Image Shape: (16, 16)
# Tree ID: 299, Optical Image Shape: (16, 16, 3)
# Tree ID: 299, Sar Image Shape: (16, 16)
# Tree ID: 300, Optical Image Shape: (16, 16, 3)
# Tree ID: 300, Sar Image Shape: (16, 16)
# Tree ID: 301, Optical Image Shape: (16, 16, 3)
# Tree ID: 301, Sar Image Shape: (16, 16)
# Tree ID: 302, Optical Image Shape: (16, 16, 3)
# Tree ID: 302, Sar Image Shape: (16, 16)
# Tree ID: 303, Optical Image Shape: (16, 16, 3)
# Tree ID: 303, Sar Image Shape: (16, 16)
# Tree ID: 304, Optical Image Shape: (16, 16, 3)
# Tree ID: 304, Sar Image Shape: (16, 16)
# Tree ID: 305, Optical Image Shape: (16, 16, 3)
# Tree ID: 305, Sar Image Shape: (16, 16)
# Tree ID: 306, Optical Image Shape: (16, 16, 3)
# Tree ID: 306, Sar Image Shape: (16, 16)
# Tree ID: 307, Optical Image Shape: (16, 16, 3)
# Tree ID: 307, Sar Image Shape: (16, 16)
# Tree ID: 308, Optical Image Shape: (16, 16, 3)
# Tree ID: 308, Sar Image Shape: (16, 16)
# Tree ID: 309, Optical Image Shape: (16, 16, 3)
# Tree ID: 309, Sar Image Shape: (16, 16)
# Tree ID: 310, Optical Image Shape: (16, 16, 3)
# Tree ID: 310, Sar Image Shape: (16, 16)
# Tree ID: 311, Optical Image Shape: (16, 16, 3)
# Tree ID: 311, Sar Image Shape: (16, 16)
# Tree ID: 312, Optical Image Shape: (16, 16, 3)
# Tree ID: 312, Sar Image Shape: (16, 16)
# Tree ID: 313, Optical Image Shape: (16, 16, 3)
# Tree ID: 313, Sar Image Shape: (16, 16)
# Tree ID: 314, Optical Image Shape: (16, 16, 3)
# Tree ID: 314, Sar Image Shape: (16, 16)
# Tree ID: 315, Optical Image Shape: (16, 16, 3)
# Tree ID: 315, Sar Image Shape: (16, 16)
# Tree ID: 316, Optical Image Shape: (16, 16, 3)
# Tree ID: 316, Sar Image Shape: (16, 16)
# Tree ID: 317, Optical Image Shape: (16, 16, 3)
# Tree ID: 317, Sar Image Shape: (16, 16)
# Tree ID: 318, Optical Image Shape: (16, 16, 3)
# Tree ID: 318, Sar Image Shape: (16, 16)
# Tree ID: 319, Optical Image Shape: (16, 16, 3)
# Tree ID: 319, Sar Image Shape: (16, 16)
# Tree ID: 320, Optical Image Shape: (16, 16, 3)
# Tree ID: 320, Sar Image Shape: (16, 16)
# Tree ID: 321, Optical Image Shape: (16, 16, 3)
# Tree ID: 321, Sar Image Shape: (16, 16)
# Tree ID: 322, Optical Image Shape: (16, 16, 3)
# Tree ID: 322, Sar Image Shape: (16, 16)
# Tree ID: 323, Optical Image Shape: (16, 16, 3)
# Tree ID: 323, Sar Image Shape: (16, 16)
# Tree ID: 324, Optical Image Shape: (16, 16, 3)
# Tree ID: 324, Sar Image Shape: (16, 16)
# Tree ID: 325, Optical Image Shape: (16, 16, 3)
# Tree ID: 325, Sar Image Shape: (16, 16)
# Tree ID: 326, Optical Image Shape: (16, 16, 3)
# Tree ID: 326, Sar Image Shape: (16, 16)
# Tree ID: 327, Optical Image Shape: (16, 16, 3)
# Tree ID: 327, Sar Image Shape: (16, 16)
# Tree ID: 328, Optical Image Shape: (16, 16, 3)
# Tree ID: 328, Sar Image Shape: (16, 16)
# Tree ID: 329, Optical Image Shape: (16, 16, 3)
# Tree ID: 329, Sar Image Shape: (16, 16)
# Tree ID: 330, Optical Image Shape: (16, 16, 3)
# Tree ID: 330, Sar Image Shape: (16, 16)
# Tree ID: 331, Optical Image Shape: (16, 16, 3)
# Tree ID: 331, Sar Image Shape: (16, 16)
# Tree ID: 332, Optical Image Shape: (16, 16, 3)
# Tree ID: 332, Sar Image Shape: (16, 16)
# Tree ID: 333, Optical Image Shape: (16, 16, 3)
# Tree ID: 333, Sar Image Shape: (16, 16)
# Tree ID: 334, Optical Image Shape: (16, 16, 3)
# Tree ID: 334, Sar Image Shape: (16, 16)
# Tree ID: 335, Optical Image Shape: (16, 16, 3)
# Tree ID: 335, Sar Image Shape: (16, 16)
# Tree ID: 336, Optical Image Shape: (16, 16, 3)
# Tree ID: 336, Sar Image Shape: (16, 16)
# Tree ID: 337, Optical Image Shape: (16, 16, 3)
# Tree ID: 337, Sar Image Shape: (16, 16)
# Tree ID: 338, Optical Image Shape: (16, 16, 3)
# Tree ID: 338, Sar Image Shape: (16, 16)
# Tree ID: 339, Optical Image Shape: (16, 16, 3)
# Tree ID: 339, Sar Image Shape: (16, 16)
# Tree ID: 340, Optical Image Shape: (16, 16, 3)
# Tree ID: 340, Sar Image Shape: (16, 16)
# Tree ID: 341, Optical Image Shape: (16, 16, 3)
# Tree ID: 341, Sar Image Shape: (16, 16)
# Tree ID: 342, Optical Image Shape: (16, 16, 3)
# Tree ID: 342, Sar Image Shape: (16, 16)
# Tree ID: 343, Optical Image Shape: (16, 16, 3)
# Tree ID: 343, Sar Image Shape: (16, 16)
# Tree ID: 344, Optical Image Shape: (16, 16, 3)
# Tree ID: 344, Sar Image Shape: (16, 16)
# Tree ID: 345, Optical Image Shape: (16, 16, 3)
# Tree ID: 345, Sar Image Shape: (16, 16)
# Tree ID: 346, Optical Image Shape: (16, 16, 3)
# Tree ID: 346, Sar Image Shape: (16, 16)
# Tree ID: 347, Optical Image Shape: (16, 16, 3)
# Tree ID: 347, Sar Image Shape: (16, 16)
# Tree ID: 348, Optical Image Shape: (16, 16, 3)
# Tree ID: 348, Sar Image Shape: (16, 16)
# Tree ID: 349, Optical Image Shape: (16, 16, 3)
# Tree ID: 349, Sar Image Shape: (16, 16)
# Tree ID: 350, Optical Image Shape: (16, 16, 3)
# Tree ID: 350, Sar Image Shape: (16, 16)
# Tree ID: 351, Optical Image Shape: (16, 16, 3)
# Tree ID: 351, Sar Image Shape: (16, 16)
# Tree ID: 352, Optical Image Shape: (16, 16, 3)
# Tree ID: 352, Sar Image Shape: (16, 16)
# Tree ID: 353, Optical Image Shape: (16, 16, 3)
# Tree ID: 353, Sar Image Shape: (16, 16)
# Tree ID: 354, Optical Image Shape: (16, 16, 3)
# Tree ID: 354, Sar Image Shape: (16, 16)
# Tree ID: 355, Optical Image Shape: (16, 16, 3)
# Tree ID: 355, Sar Image Shape: (16, 16)
# Tree ID: 356, Optical Image Shape: (16, 16, 3)
# Tree ID: 356, Sar Image Shape: (16, 16)
# Tree ID: 357, Optical Image Shape: (16, 16, 3)
# Tree ID: 357, Sar Image Shape: (16, 16)
# Tree ID: 358, Optical Image Shape: (16, 16, 3)
# Tree ID: 358, Sar Image Shape: (16, 16)
# Tree ID: 359, Optical Image Shape: (16, 16, 3)
# Tree ID: 359, Sar Image Shape: (16, 16)
# Tree ID: 360, Optical Image Shape: (16, 16, 3)
# Tree ID: 360, Sar Image Shape: (16, 16)
# Tree ID: 361, Optical Image Shape: (16, 16, 3)
# Tree ID: 361, Sar Image Shape: (16, 16)
# Tree ID: 362, Optical Image Shape: (16, 16, 3)
# Tree ID: 362, Sar Image Shape: (16, 16)
# Tree ID: 363, Optical Image Shape: (16, 16, 3)
# Tree ID: 363, Sar Image Shape: (16, 16)
# Tree ID: 364, Optical Image Shape: (16, 16, 3)
# Tree ID: 364, Sar Image Shape: (16, 16)
# Tree ID: 365, Optical Image Shape: (16, 16, 3)
# Tree ID: 365, Sar Image Shape: (16, 16)
# Tree ID: 366, Optical Image Shape: (16, 16, 3)
# Tree ID: 366, Sar Image Shape: (16, 16)
# Tree ID: 367, Optical Image Shape: (16, 16, 3)
# Tree ID: 367, Sar Image Shape: (16, 16)
# Tree ID: 368, Optical Image Shape: (16, 16, 3)
# Tree ID: 368, Sar Image Shape: (16, 16)
# Tree ID: 369, Optical Image Shape: (16, 16, 3)
# Tree ID: 369, Sar Image Shape: (16, 16)
# Tree ID: 370, Optical Image Shape: (16, 16, 3)
# Tree ID: 370, Sar Image Shape: (16, 16)
# Tree ID: 371, Optical Image Shape: (16, 16, 3)
# Tree ID: 371, Sar Image Shape: (16, 16)
# Tree ID: 372, Optical Image Shape: (16, 16, 3)
# Tree ID: 372, Sar Image Shape: (16, 16)
# Tree ID: 373, Optical Image Shape: (16, 16, 3)
# Tree ID: 373, Sar Image Shape: (16, 16)
# Tree ID: 374, Optical Image Shape: (16, 16, 3)
# Tree ID: 374, Sar Image Shape: (16, 16)
# Tree ID: 375, Optical Image Shape: (16, 16, 3)
# Tree ID: 375, Sar Image Shape: (16, 16)
# Tree ID: 376, Optical Image Shape: (16, 16, 3)
# Tree ID: 376, Sar Image Shape: (16, 16)
# Tree ID: 377, Optical Image Shape: (16, 16, 3)
# Tree ID: 377, Sar Image Shape: (16, 16)
# Tree ID: 378, Optical Image Shape: (16, 16, 3)
# Tree ID: 378, Sar Image Shape: (16, 16)
# Tree ID: 379, Optical Image Shape: (16, 16, 3)
# Tree ID: 379, Sar Image Shape: (16, 16)
# Tree ID: 380, Optical Image Shape: (16, 16, 3)
# Tree ID: 380, Sar Image Shape: (16, 16)
# Tree ID: 381, Optical Image Shape: (16, 16, 3)
# Tree ID: 381, Sar Image Shape: (16, 16)
# Tree ID: 382, Optical Image Shape: (16, 16, 3)
# Tree ID: 382, Sar Image Shape: (16, 16)
# Tree ID: 383, Optical Image Shape: (16, 16, 3)
# Tree ID: 383, Sar Image Shape: (16, 16)
# Tree ID: 384, Optical Image Shape: (16, 16, 3)
# Tree ID: 384, Sar Image Shape: (16, 16)
# Tree ID: 385, Optical Image Shape: (16, 16, 3)
# Tree ID: 385, Sar Image Shape: (16, 16)
# Tree ID: 386, Optical Image Shape: (16, 16, 3)
# Tree ID: 386, Sar Image Shape: (16, 16)
# Tree ID: 387, Optical Image Shape: (16, 16, 3)
# Tree ID: 387, Sar Image Shape: (16, 16)
# Tree ID: 388, Optical Image Shape: (16, 16, 3)
# Tree ID: 388, Sar Image Shape: (16, 16)
# Tree ID: 389, Optical Image Shape: (16, 16, 3)
# Tree ID: 389, Sar Image Shape: (16, 16)
# Tree ID: 390, Optical Image Shape: (16, 16, 3)
# Tree ID: 390, Sar Image Shape: (16, 16)
# Tree ID: 391, Optical Image Shape: (16, 16, 3)
# Tree ID: 391, Sar Image Shape: (16, 16)
# Tree ID: 392, Optical Image Shape: (16, 16, 3)
# Tree ID: 392, Sar Image Shape: (16, 16)
# Tree ID: 393, Optical Image Shape: (16, 16, 3)
# Tree ID: 393, Sar Image Shape: (16, 16)
# Tree ID: 394, Optical Image Shape: (16, 16, 3)
# Tree ID: 394, Sar Image Shape: (16, 16)
# Tree ID: 395, Optical Image Shape: (16, 16, 3)
# Tree ID: 395, Sar Image Shape: (16, 16)
# Tree ID: 396, Optical Image Shape: (16, 16, 3)
# Tree ID: 396, Sar Image Shape: (16, 16)
# Tree ID: 397, Optical Image Shape: (16, 16, 3)
# Tree ID: 397, Sar Image Shape: (16, 16)
# Tree ID: 398, Optical Image Shape: (16, 16, 3)
# Tree ID: 398, Sar Image Shape: (16, 16)
# Tree ID: 399, Optical Image Shape: (16, 16, 3)
# Tree ID: 399, Sar Image Shape: (16, 16)
# Tree ID: 400, Optical Image Shape: (16, 16, 3)
# Tree ID: 400, Sar Image Shape: (16, 16)
# Tree ID: 401, Optical Image Shape: (16, 16, 3)
# Tree ID: 401, Sar Image Shape: (16, 16)
# Tree ID: 402, Optical Image Shape: (16, 16, 3)
# Tree ID: 402, Sar Image Shape: (16, 16)
# Tree ID: 403, Optical Image Shape: (16, 16, 3)
# Tree ID: 403, Sar Image Shape: (16, 16)
# Tree ID: 404, Optical Image Shape: (16, 16, 3)
# Tree ID: 404, Sar Image Shape: (16, 16)
# Tree ID: 405, Optical Image Shape: (16, 16, 3)
# Tree ID: 405, Sar Image Shape: (16, 16)
# Tree ID: 406, Optical Image Shape: (16, 16, 3)
# Tree ID: 406, Sar Image Shape: (16, 16)
# Tree ID: 407, Optical Image Shape: (16, 16, 3)
# Tree ID: 407, Sar Image Shape: (16, 16)
# Tree ID: 408, Optical Image Shape: (16, 16, 3)
# Tree ID: 408, Sar Image Shape: (16, 16)
# Tree ID: 409, Optical Image Shape: (16, 16, 3)
# Tree ID: 409, Sar Image Shape: (16, 16)
# Tree ID: 410, Optical Image Shape: (16, 16, 3)
# Tree ID: 410, Sar Image Shape: (16, 16)
# Tree ID: 411, Optical Image Shape: (16, 16, 3)
# Tree ID: 411, Sar Image Shape: (16, 16)
# Tree ID: 412, Optical Image Shape: (16, 16, 3)
# Tree ID: 412, Sar Image Shape: (16, 16)
# Tree ID: 413, Optical Image Shape: (16, 16, 3)
# Tree ID: 413, Sar Image Shape: (16, 16)
# Tree ID: 414, Optical Image Shape: (16, 16, 3)
# Tree ID: 414, Sar Image Shape: (16, 16)
# Tree ID: 415, Optical Image Shape: (16, 16, 3)
# Tree ID: 415, Sar Image Shape: (16, 16)
# Tree ID: 416, Optical Image Shape: (16, 16, 3)
# Tree ID: 416, Sar Image Shape: (16, 16)
# Tree ID: 417, Optical Image Shape: (16, 16, 3)
# Tree ID: 417, Sar Image Shape: (16, 16)
# Tree ID: 418, Optical Image Shape: (16, 16, 3)
# Tree ID: 418, Sar Image Shape: (16, 16)
# Tree ID: 419, Optical Image Shape: (16, 16, 3)
# Tree ID: 419, Sar Image Shape: (16, 16)
# Tree ID: 420, Optical Image Shape: (16, 16, 3)
# Tree ID: 420, Sar Image Shape: (16, 16)
# Tree ID: 421, Optical Image Shape: (16, 16, 3)
# Tree ID: 421, Sar Image Shape: (16, 16)
# Tree ID: 422, Optical Image Shape: (16, 16, 3)
# Tree ID: 422, Sar Image Shape: (16, 16)
# Tree ID: 423, Optical Image Shape: (16, 16, 3)
# Tree ID: 423, Sar Image Shape: (16, 16)
# Tree ID: 424, Optical Image Shape: (16, 16, 3)
# Tree ID: 424, Sar Image Shape: (16, 16)
# Tree ID: 425, Optical Image Shape: (16, 16, 3)
# Tree ID: 425, Sar Image Shape: (16, 16)
# Tree ID: 426, Optical Image Shape: (16, 16, 3)
# Tree ID: 426, Sar Image Shape: (16, 16)
# Tree ID: 427, Optical Image Shape: (16, 16, 3)
# Tree ID: 427, Sar Image Shape: (16, 16)
# Tree ID: 428, Optical Image Shape: (16, 16, 3)
# Tree ID: 428, Sar Image Shape: (16, 16)
# Tree ID: 429, Optical Image Shape: (16, 16, 3)
# Tree ID: 429, Sar Image Shape: (16, 16)
# Tree ID: 430, Optical Image Shape: (16, 16, 3)
# Tree ID: 430, Sar Image Shape: (16, 16)
# Tree ID: 431, Optical Image Shape: (16, 16, 3)
# Tree ID: 431, Sar Image Shape: (16, 16)
# Tree ID: 432, Optical Image Shape: (16, 16, 3)
# Tree ID: 432, Sar Image Shape: (16, 16)
# Tree ID: 433, Optical Image Shape: (16, 16, 3)
# Tree ID: 433, Sar Image Shape: (16, 16)
# Tree ID: 434, Optical Image Shape: (16, 16, 3)
# Tree ID: 434, Sar Image Shape: (16, 16)
# Tree ID: 435, Optical Image Shape: (16, 16, 3)
# Tree ID: 435, Sar Image Shape: (16, 16)
# Tree ID: 436, Optical Image Shape: (16, 16, 3)
# Tree ID: 436, Sar Image Shape: (16, 16)
# Tree ID: 437, Optical Image Shape: (16, 16, 3)
# Tree ID: 437, Sar Image Shape: (16, 16)
# Tree ID: 438, Optical Image Shape: (16, 16, 3)
# Tree ID: 438, Sar Image Shape: (16, 16)
# Tree ID: 439, Optical Image Shape: (16, 16, 3)
# Tree ID: 439, Sar Image Shape: (16, 16)
# Tree ID: 440, Optical Image Shape: (16, 16, 3)
# Tree ID: 440, Sar Image Shape: (16, 16)
# Tree ID: 441, Optical Image Shape: (16, 16, 3)
# Tree ID: 441, Sar Image Shape: (16, 16)
# Tree ID: 442, Optical Image Shape: (16, 16, 3)
# Tree ID: 442, Sar Image Shape: (16, 16)
# Tree ID: 443, Optical Image Shape: (16, 16, 3)
# Tree ID: 443, Sar Image Shape: (16, 16)
# Tree ID: 444, Optical Image Shape: (16, 16, 3)
# Tree ID: 444, Sar Image Shape: (16, 16)
# Tree ID: 445, Optical Image Shape: (16, 16, 3)
# Tree ID: 445, Sar Image Shape: (16, 16)
# Tree ID: 446, Optical Image Shape: (16, 16, 3)
# Tree ID: 446, Sar Image Shape: (16, 16)
# Tree ID: 447, Optical Image Shape: (16, 16, 3)
# Tree ID: 447, Sar Image Shape: (16, 16)
# Tree ID: 448, Optical Image Shape: (16, 16, 3)
# Tree ID: 448, Sar Image Shape: (16, 16)
# Tree ID: 449, Optical Image Shape: (16, 16, 3)
# Tree ID: 449, Sar Image Shape: (16, 16)
# Tree ID: 450, Optical Image Shape: (16, 16, 3)
# Tree ID: 450, Sar Image Shape: (16, 16)
# Tree ID: 451, Optical Image Shape: (16, 16, 3)
# Tree ID: 451, Sar Image Shape: (16, 16)
# Tree ID: 452, Optical Image Shape: (16, 16, 3)
# Tree ID: 452, Sar Image Shape: (16, 16)
# Tree ID: 453, Optical Image Shape: (16, 16, 3)
# Tree ID: 453, Sar Image Shape: (16, 16)
# Tree ID: 454, Optical Image Shape: (16, 16, 3)
# Tree ID: 454, Sar Image Shape: (16, 16)
# Tree ID: 455, Optical Image Shape: (16, 16, 3)
# Tree ID: 455, Sar Image Shape: (16, 16)
# Tree ID: 456, Optical Image Shape: (16, 16, 3)
# Tree ID: 456, Sar Image Shape: (16, 16)
# Tree ID: 457, Optical Image Shape: (16, 16, 3)
# Tree ID: 457, Sar Image Shape: (16, 16)
# Tree ID: 458, Optical Image Shape: (16, 16, 3)
# Tree ID: 458, Sar Image Shape: (16, 16)
# Tree ID: 459, Optical Image Shape: (16, 16, 3)
# Tree ID: 459, Sar Image Shape: (16, 16)
# Tree ID: 460, Optical Image Shape: (16, 16, 3)
# Tree ID: 460, Sar Image Shape: (16, 16)
# Tree ID: 461, Optical Image Shape: (16, 16, 3)
# Tree ID: 461, Sar Image Shape: (16, 16)
# Tree ID: 462, Optical Image Shape: (16, 16, 3)
# Tree ID: 462, Sar Image Shape: (16, 16)
# Tree ID: 463, Optical Image Shape: (16, 16, 3)
# Tree ID: 463, Sar Image Shape: (16, 16)
# Tree ID: 464, Optical Image Shape: (16, 16, 3)
# Tree ID: 464, Sar Image Shape: (16, 16)
# Tree ID: 465, Optical Image Shape: (16, 16, 3)
# Tree ID: 465, Sar Image Shape: (16, 16)
# Tree ID: 466, Optical Image Shape: (16, 16, 3)
# Tree ID: 466, Sar Image Shape: (16, 16)
# Tree ID: 467, Optical Image Shape: (16, 16, 3)
# Tree ID: 467, Sar Image Shape: (16, 16)
# Tree ID: 468, Optical Image Shape: (16, 16, 3)
# Tree ID: 468, Sar Image Shape: (16, 16)
# Tree ID: 469, Optical Image Shape: (16, 16, 3)
# Tree ID: 469, Sar Image Shape: (16, 16)
# Tree ID: 470, Optical Image Shape: (16, 16, 3)
# Tree ID: 470, Sar Image Shape: (16, 16)
# Tree ID: 471, Optical Image Shape: (16, 16, 3)
# Tree ID: 471, Sar Image Shape: (16, 16)
# Tree ID: 472, Optical Image Shape: (16, 16, 3)
# Tree ID: 472, Sar Image Shape: (16, 16)
# Tree ID: 473, Optical Image Shape: (16, 16, 3)
# Tree ID: 473, Sar Image Shape: (16, 16)
# Tree ID: 474, Optical Image Shape: (16, 16, 3)
# Tree ID: 474, Sar Image Shape: (16, 16)
# Tree ID: 475, Optical Image Shape: (16, 16, 3)
# Tree ID: 475, Sar Image Shape: (16, 16)
# Tree ID: 476, Optical Image Shape: (16, 16, 3)
# Tree ID: 476, Sar Image Shape: (16, 16)
# Tree ID: 477, Optical Image Shape: (16, 16, 3)
# Tree ID: 477, Sar Image Shape: (16, 16)
# Tree ID: 478, Optical Image Shape: (16, 16, 3)
# Tree ID: 478, Sar Image Shape: (16, 16)
# Tree ID: 479, Optical Image Shape: (16, 16, 3)
# Tree ID: 479, Sar Image Shape: (16, 16)
# Tree ID: 480, Optical Image Shape: (16, 16, 3)
# Tree ID: 480, Sar Image Shape: (16, 16)
# Tree ID: 481, Optical Image Shape: (16, 16, 3)
# Tree ID: 481, Sar Image Shape: (16, 16)
# Tree ID: 482, Optical Image Shape: (16, 16, 3)
# Tree ID: 482, Sar Image Shape: (16, 16)
# Tree ID: 483, Optical Image Shape: (16, 16, 3)
# Tree ID: 483, Sar Image Shape: (16, 16)
# Tree ID: 484, Optical Image Shape: (16, 16, 3)
# Tree ID: 484, Sar Image Shape: (16, 16)
# Tree ID: 485, Optical Image Shape: (16, 16, 3)
# Tree ID: 485, Sar Image Shape: (16, 16)
# Tree ID: 486, Optical Image Shape: (16, 16, 3)
# Tree ID: 486, Sar Image Shape: (16, 16)
# Tree ID: 487, Optical Image Shape: (16, 16, 3)
# Tree ID: 487, Sar Image Shape: (16, 16)
# Tree ID: 488, Optical Image Shape: (16, 16, 3)
# Tree ID: 488, Sar Image Shape: (16, 16)
# Tree ID: 489, Optical Image Shape: (16, 16, 3)
# Tree ID: 489, Sar Image Shape: (16, 16)
# Tree ID: 490, Optical Image Shape: (16, 16, 3)
# Tree ID: 490, Sar Image Shape: (16, 16)
# Tree ID: 491, Optical Image Shape: (16, 16, 3)
# Tree ID: 491, Sar Image Shape: (16, 16)
# Tree ID: 492, Optical Image Shape: (16, 16, 3)
# Tree ID: 492, Sar Image Shape: (16, 16)
# Tree ID: 493, Optical Image Shape: (16, 16, 3)
# Tree ID: 493, Sar Image Shape: (16, 16)
# Tree ID: 494, Optical Image Shape: (16, 16, 3)
# Tree ID: 494, Sar Image Shape: (16, 16)
# Tree ID: 495, Optical Image Shape: (16, 16, 3)
# Tree ID: 495, Sar Image Shape: (16, 16)
# Tree ID: 496, Optical Image Shape: (16, 16, 3)
# Tree ID: 496, Sar Image Shape: (16, 16)
# Tree ID: 497, Optical Image Shape: (16, 16, 3)
# Tree ID: 497, Sar Image Shape: (16, 16)
# Tree ID: 498, Optical Image Shape: (16, 16, 3)
# Tree ID: 498, Sar Image Shape: (16, 16)
# Tree ID: 499, Optical Image Shape: (16, 16, 3)
# Tree ID: 499, Sar Image Shape: (16, 16)
# Tree ID: 500, Optical Image Shape: (16, 16, 3)
# Tree ID: 500, Sar Image Shape: (16, 16)
# Tree ID: 501, Optical Image Shape: (16, 16, 3)
# Tree ID: 501, Sar Image Shape: (16, 16)
# Tree ID: 502, Optical Image Shape: (16, 16, 3)
# Tree ID: 502, Sar Image Shape: (16, 16)
# Tree ID: 503, Optical Image Shape: (16, 16, 3)
# Tree ID: 503, Sar Image Shape: (16, 16)
# Tree ID: 504, Optical Image Shape: (16, 16, 3)
# Tree ID: 504, Sar Image Shape: (16, 16)
# Tree ID: 505, Optical Image Shape: (16, 16, 3)
# Tree ID: 505, Sar Image Shape: (16, 16)
# Tree ID: 506, Optical Image Shape: (16, 16, 3)
# Tree ID: 506, Sar Image Shape: (16, 16)
# Tree ID: 507, Optical Image Shape: (16, 16, 3)
# Tree ID: 507, Sar Image Shape: (16, 16)
# Tree ID: 508, Optical Image Shape: (16, 16, 3)
# Tree ID: 508, Sar Image Shape: (16, 16)
# Tree ID: 509, Optical Image Shape: (16, 16, 3)
# Tree ID: 509, Sar Image Shape: (16, 16)
# Tree ID: 510, Optical Image Shape: (16, 16, 3)
# Tree ID: 510, Sar Image Shape: (16, 16)
# Tree ID: 511, Optical Image Shape: (16, 16, 3)
# Tree ID: 511, Sar Image Shape: (16, 16)
# Tree ID: 512, Optical Image Shape: (16, 16, 3)
# Tree ID: 512, Sar Image Shape: (16, 16)
# Tree ID: 513, Optical Image Shape: (16, 16, 3)
# Tree ID: 513, Sar Image Shape: (16, 16)
# Tree ID: 514, Optical Image Shape: (16, 16, 3)
# Tree ID: 514, Sar Image Shape: (16, 16)
# Tree ID: 515, Optical Image Shape: (16, 16, 3)
# Tree ID: 515, Sar Image Shape: (16, 16)
# Tree ID: 516, Optical Image Shape: (16, 16, 3)
# Tree ID: 516, Sar Image Shape: (16, 16)
# Tree ID: 517, Optical Image Shape: (16, 16, 3)
# Tree ID: 517, Sar Image Shape: (16, 16)
# Tree ID: 518, Optical Image Shape: (16, 16, 3)
# Tree ID: 518, Sar Image Shape: (16, 16)
# Tree ID: 519, Optical Image Shape: (16, 16, 3)
# Tree ID: 519, Sar Image Shape: (16, 16)
# Tree ID: 520, Optical Image Shape: (16, 16, 3)
# Tree ID: 520, Sar Image Shape: (16, 16)
# Tree ID: 521, Optical Image Shape: (16, 16, 3)
# Tree ID: 521, Sar Image Shape: (16, 16)
# Tree ID: 522, Optical Image Shape: (16, 16, 3)
# Tree ID: 522, Sar Image Shape: (16, 16)
# Tree ID: 523, Optical Image Shape: (16, 16, 3)
# Tree ID: 523, Sar Image Shape: (16, 16)
# Tree ID: 524, Optical Image Shape: (16, 16, 3)
# Tree ID: 524, Sar Image Shape: (16, 16)
# Tree ID: 525, Optical Image Shape: (16, 16, 3)
# Tree ID: 525, Sar Image Shape: (16, 16)
# Tree ID: 526, Optical Image Shape: (16, 16, 3)
# Tree ID: 526, Sar Image Shape: (16, 16)
# Tree ID: 527, Optical Image Shape: (16, 16, 3)
# Tree ID: 527, Sar Image Shape: (16, 16)
# Tree ID: 528, Optical Image Shape: (16, 16, 3)
# Tree ID: 528, Sar Image Shape: (16, 16)
# Tree ID: 529, Optical Image Shape: (16, 16, 3)
# Tree ID: 529, Sar Image Shape: (16, 16)
# Tree ID: 531, Optical Image Shape: (16, 16, 3)
# Tree ID: 531, Sar Image Shape: (16, 16)
# Tree ID: 532, Optical Image Shape: (16, 16, 3)
# Tree ID: 532, Sar Image Shape: (16, 16)
# Tree ID: 533, Optical Image Shape: (16, 16, 3)
# Tree ID: 533, Sar Image Shape: (16, 16)
# Tree ID: 534, Optical Image Shape: (16, 16, 3)
# Tree ID: 534, Sar Image Shape: (16, 16)
# Tree ID: 535, Optical Image Shape: (16, 16, 3)
# Tree ID: 535, Sar Image Shape: (16, 16)
# Tree ID: 536, Optical Image Shape: (16, 16, 3)
# Tree ID: 536, Sar Image Shape: (16, 16)
# Tree ID: 537, Optical Image Shape: (16, 16, 3)
# Tree ID: 537, Sar Image Shape: (16, 16)
# Tree ID: 538, Optical Image Shape: (16, 16, 3)
# Tree ID: 538, Sar Image Shape: (16, 16)
# Tree ID: 539, Optical Image Shape: (16, 16, 3)
# Tree ID: 539, Sar Image Shape: (16, 16)
# Tree ID: 540, Optical Image Shape: (16, 16, 3)
# Tree ID: 540, Sar Image Shape: (16, 16)
# Tree ID: 541, Optical Image Shape: (16, 16, 3)
# Tree ID: 541, Sar Image Shape: (16, 16)
# Tree ID: 542, Optical Image Shape: (16, 16, 3)
# Tree ID: 542, Sar Image Shape: (16, 16)
# Tree ID: 543, Optical Image Shape: (16, 16, 3)
# Tree ID: 543, Sar Image Shape: (16, 16)
# Tree ID: 544, Optical Image Shape: (16, 16, 3)
# Tree ID: 544, Sar Image Shape: (16, 16)
# Tree ID: 545, Optical Image Shape: (16, 16, 3)
# Tree ID: 545, Sar Image Shape: (16, 16)
# Tree ID: 546, Optical Image Shape: (16, 16, 3)
# Tree ID: 546, Sar Image Shape: (16, 16)
# Tree ID: 547, Optical Image Shape: (16, 16, 3)
# Tree ID: 547, Sar Image Shape: (16, 16)
# Tree ID: 548, Optical Image Shape: (16, 16, 3)
# Tree ID: 548, Sar Image Shape: (16, 16)
# Tree ID: 549, Optical Image Shape: (16, 16, 3)
# Tree ID: 549, Sar Image Shape: (16, 16)
# Tree ID: 550, Optical Image Shape: (16, 16, 3)
# Tree ID: 550, Sar Image Shape: (16, 16)
# Tree ID: 551, Optical Image Shape: (16, 16, 3)
# Tree ID: 551, Sar Image Shape: (16, 16)
# Tree ID: 552, Optical Image Shape: (16, 16, 3)
# Tree ID: 552, Sar Image Shape: (16, 16)
# Tree ID: 553, Optical Image Shape: (16, 16, 3)
# Tree ID: 553, Sar Image Shape: (16, 16)
# Tree ID: 554, Optical Image Shape: (16, 16, 3)
# Tree ID: 554, Sar Image Shape: (16, 16)
# Tree ID: 555, Optical Image Shape: (16, 16, 3)
# Tree ID: 555, Sar Image Shape: (16, 16)
# Tree ID: 556, Optical Image Shape: (16, 16, 3)
# Tree ID: 556, Sar Image Shape: (16, 16)
# ...
# Tree ID: 30511, Sar Image Shape: (16, 16)
# Tree ID: 30512, Optical Image Shape: (16, 16, 3)
# Tree ID: 30512, Sar Image Shape: (16, 16)
# Tree ID: 30513, Optical Image Shape: (16, 16, 3)
# Tree ID: 30513, Sar Image Shape: (16, 16)
# Tree ID: 30514, Optical Image Shape: (16, 16, 3)
# Tree ID: 30514, Sar Image Shape: (16, 16)
# Tree ID: 30515, Optical Image Shape: (16, 16, 3)
# Tree ID: 30515, Sar Image Shape: (16, 16)
# Tree ID: 30516, Optical Image Shape: (16, 16, 3)
# Tree ID: 30516, Sar Image Shape: (16, 16)
# Tree ID: 30517, Optical Image Shape: (16, 16, 3)
# Tree ID: 30517, Sar Image Shape: (16, 16)
# Tree ID: 30518, Optical Image Shape: (16, 16, 3)
# Tree ID: 30518, Sar Image Shape: (16, 16)
# Tree ID: 30519, Optical Image Shape: (16, 16, 3)
# Tree ID: 30519, Sar Image Shape: (16, 16)
# Tree ID: 30520, Optical Image Shape: (16, 16, 3)
# Tree ID: 30520, Sar Image Shape: (16, 16)
# Tree ID: 30521, Optical Image Shape: (16, 16, 3)
# Tree ID: 30521, Sar Image Shape: (16, 16)
# Tree ID: 30522, Optical Image Shape: (16, 16, 3)
# Tree ID: 30522, Sar Image Shape: (16, 16)
# Tree ID: 30523, Optical Image Shape: (16, 16, 3)
# Tree ID: 30523, Sar Image Shape: (16, 16)
# Tree ID: 30524, Optical Image Shape: (16, 16, 3)
# Tree ID: 30524, Sar Image Shape: (16, 16)
# Tree ID: 30525, Optical Image Shape: (16, 16, 3)
# Tree ID: 30525, Sar Image Shape: (16, 16)
# Tree ID: 30526, Optical Image Shape: (16, 16, 3)
# Tree ID: 30526, Sar Image Shape: (16, 16)
# Tree ID: 30527, Optical Image Shape: (16, 16, 3)
# Tree ID: 30527, Sar Image Shape: (16, 16)
# Tree ID: 30528, Optical Image Shape: (16, 16, 3)
# Tree ID: 30528, Sar Image Shape: (16, 16)
# Tree ID: 30529, Optical Image Shape: (16, 16, 3)
# Tree ID: 30529, Sar Image Shape: (16, 16)
# Tree ID: 30530, Optical Image Shape: (16, 16, 3)
# Tree ID: 30530, Sar Image Shape: (16, 16)
# Tree ID: 30531, Optical Image Shape: (16, 16, 3)
# Tree ID: 30531, Sar Image Shape: (16, 16)
# Tree ID: 30532, Optical Image Shape: (16, 16, 3)
# Tree ID: 30532, Sar Image Shape: (16, 16)
# Tree ID: 30533, Optical Image Shape: (16, 16, 3)
# Tree ID: 30533, Sar Image Shape: (16, 16)
# Tree ID: 30534, Optical Image Shape: (16, 16, 3)
# Tree ID: 30534, Sar Image Shape: (16, 16)
# Tree ID: 30535, Optical Image Shape: (16, 16, 3)
# Tree ID: 30535, Sar Image Shape: (16, 16)
# Tree ID: 30536, Optical Image Shape: (16, 16, 3)
# Tree ID: 30536, Sar Image Shape: (16, 16)
# Tree ID: 30537, Optical Image Shape: (16, 16, 3)
# Tree ID: 30537, Sar Image Shape: (16, 16)
# Tree ID: 30538, Optical Image Shape: (16, 16, 3)
# Tree ID: 30538, Sar Image Shape: (16, 16)
# Tree ID: 30539, Optical Image Shape: (16, 16, 3)
# Tree ID: 30539, Sar Image Shape: (16, 16)
# Tree ID: 30540, Optical Image Shape: (16, 16, 3)
# Tree ID: 30540, Sar Image Shape: (16, 16)
# Tree ID: 30541, Optical Image Shape: (16, 16, 3)
# Tree ID: 30541, Sar Image Shape: (16, 16)
# Tree ID: 30542, Optical Image Shape: (16, 16, 3)
# Tree ID: 30542, Sar Image Shape: (16, 16)
# Tree ID: 30543, Optical Image Shape: (16, 16, 3)
# Tree ID: 30543, Sar Image Shape: (16, 16)
# Tree ID: 30544, Optical Image Shape: (16, 16, 3)
# Tree ID: 30544, Sar Image Shape: (16, 16)
# Tree ID: 30545, Optical Image Shape: (16, 16, 3)
# Tree ID: 30545, Sar Image Shape: (16, 16)
# Tree ID: 30546, Optical Image Shape: (16, 16, 3)
# Tree ID: 30546, Sar Image Shape: (16, 16)
# Tree ID: 30547, Optical Image Shape: (16, 16, 3)
# Tree ID: 30547, Sar Image Shape: (16, 16)
# Tree ID: 30548, Optical Image Shape: (16, 16, 3)
# Tree ID: 30548, Sar Image Shape: (16, 16)
# Tree ID: 30549, Optical Image Shape: (16, 16, 3)
# Tree ID: 30549, Sar Image Shape: (16, 16)
# Tree ID: 30550, Optical Image Shape: (16, 16, 3)
# Tree ID: 30550, Sar Image Shape: (16, 16)
# Tree ID: 30551, Optical Image Shape: (16, 16, 3)
# Tree ID: 30551, Sar Image Shape: (16, 16)
# Tree ID: 30552, Optical Image Shape: (16, 16, 3)
# Tree ID: 30552, Sar Image Shape: (16, 16)
# Tree ID: 30553, Optical Image Shape: (16, 16, 3)
# Tree ID: 30553, Sar Image Shape: (16, 16)
# Tree ID: 30554, Optical Image Shape: (16, 16, 3)
# Tree ID: 30554, Sar Image Shape: (16, 16)
# Tree ID: 30555, Optical Image Shape: (16, 16, 3)
# Tree ID: 30555, Sar Image Shape: (16, 16)
# Tree ID: 30556, Optical Image Shape: (16, 16, 3)
# Tree ID: 30556, Sar Image Shape: (16, 16)
# Tree ID: 30557, Optical Image Shape: (16, 16, 3)
# Tree ID: 30557, Sar Image Shape: (16, 16)
# Tree ID: 30558, Optical Image Shape: (16, 16, 3)
# Tree ID: 30558, Sar Image Shape: (16, 16)
# Tree ID: 30559, Optical Image Shape: (16, 16, 3)
# Tree ID: 30559, Sar Image Shape: (16, 16)
# Tree ID: 30560, Optical Image Shape: (16, 16, 3)
# Tree ID: 30560, Sar Image Shape: (16, 16)
# Tree ID: 30561, Optical Image Shape: (16, 16, 3)
# Tree ID: 30561, Sar Image Shape: (16, 16)
# Tree ID: 30562, Optical Image Shape: (16, 16, 3)
# Tree ID: 30562, Sar Image Shape: (16, 16)
# Tree ID: 30563, Optical Image Shape: (16, 16, 3)
# Tree ID: 30563, Sar Image Shape: (16, 16)
# Tree ID: 30564, Optical Image Shape: (16, 16, 3)
# Tree ID: 30564, Sar Image Shape: (16, 16)
# Tree ID: 30565, Optical Image Shape: (16, 16, 3)
# Tree ID: 30565, Sar Image Shape: (16, 16)
# Tree ID: 30566, Optical Image Shape: (16, 16, 3)
# Tree ID: 30566, Sar Image Shape: (16, 16)
# Tree ID: 30567, Optical Image Shape: (16, 16, 3)
# Tree ID: 30567, Sar Image Shape: (16, 16)
# Tree ID: 30568, Optical Image Shape: (16, 16, 3)
# Tree ID: 30568, Sar Image Shape: (16, 16)
# Tree ID: 30569, Optical Image Shape: (16, 16, 3)
# Tree ID: 30569, Sar Image Shape: (16, 16)
# Tree ID: 30570, Optical Image Shape: (16, 16, 3)
# Tree ID: 30570, Sar Image Shape: (16, 16)
# Tree ID: 30571, Optical Image Shape: (16, 16, 3)
# Tree ID: 30571, Sar Image Shape: (16, 16)
# Tree ID: 30572, Optical Image Shape: (16, 16, 3)
# Tree ID: 30572, Sar Image Shape: (16, 16)
# Tree ID: 30573, Optical Image Shape: (16, 16, 3)
# Tree ID: 30573, Sar Image Shape: (16, 16)
# Tree ID: 30574, Optical Image Shape: (16, 16, 3)
# Tree ID: 30574, Sar Image Shape: (16, 16)
# Tree ID: 30575, Optical Image Shape: (16, 16, 3)
# Tree ID: 30575, Sar Image Shape: (16, 16)
# Tree ID: 30576, Optical Image Shape: (16, 16, 3)
# Tree ID: 30576, Sar Image Shape: (16, 16)
# Tree ID: 30577, Optical Image Shape: (16, 16, 3)
# Tree ID: 30577, Sar Image Shape: (16, 16)
# Tree ID: 30578, Optical Image Shape: (16, 16, 3)
# Tree ID: 30578, Sar Image Shape: (16, 16)
# Tree ID: 30579, Optical Image Shape: (16, 16, 3)
# Tree ID: 30579, Sar Image Shape: (16, 16)
# Tree ID: 30580, Optical Image Shape: (16, 16, 3)
# Tree ID: 30580, Sar Image Shape: (16, 16)
# Tree ID: 30581, Optical Image Shape: (16, 16, 3)
# Tree ID: 30581, Sar Image Shape: (16, 16)
# Tree ID: 30582, Optical Image Shape: (16, 16, 3)
# Tree ID: 30582, Sar Image Shape: (16, 16)
# Tree ID: 30583, Optical Image Shape: (16, 16, 3)
# Tree ID: 30583, Sar Image Shape: (16, 16)
# Tree ID: 30584, Optical Image Shape: (16, 16, 3)
# Tree ID: 30584, Sar Image Shape: (16, 16)
# Tree ID: 30585, Optical Image Shape: (16, 16, 3)
# Tree ID: 30585, Sar Image Shape: (16, 16)
# Tree ID: 30586, Optical Image Shape: (16, 16, 3)
# Tree ID: 30586, Sar Image Shape: (16, 16)
# Tree ID: 30587, Optical Image Shape: (16, 16, 3)
# Tree ID: 30587, Sar Image Shape: (16, 16)
# Tree ID: 30588, Optical Image Shape: (16, 16, 3)
# Tree ID: 30588, Sar Image Shape: (16, 16)
# Tree ID: 30589, Optical Image Shape: (16, 16, 3)
# Tree ID: 30589, Sar Image Shape: (16, 16)
# Tree ID: 30590, Optical Image Shape: (16, 16, 3)
# Tree ID: 30590, Sar Image Shape: (16, 16)
# Tree ID: 30591, Optical Image Shape: (16, 16, 3)
# Tree ID: 30591, Sar Image Shape: (16, 16)
# Tree ID: 30592, Optical Image Shape: (16, 16, 3)
# Tree ID: 30592, Sar Image Shape: (16, 16)
# Tree ID: 30593, Optical Image Shape: (16, 16, 3)
# Tree ID: 30593, Sar Image Shape: (16, 16)
# Tree ID: 30594, Optical Image Shape: (16, 16, 3)
# Tree ID: 30594, Sar Image Shape: (16, 16)
# Tree ID: 30595, Optical Image Shape: (16, 16, 3)
# Tree ID: 30595, Sar Image Shape: (16, 16)
# Tree ID: 30596, Optical Image Shape: (16, 16, 3)
# Tree ID: 30596, Sar Image Shape: (16, 16)
# Tree ID: 30597, Optical Image Shape: (16, 16, 3)
# Tree ID: 30597, Sar Image Shape: (16, 16)
# Tree ID: 30598, Optical Image Shape: (16, 16, 3)
# Tree ID: 30598, Sar Image Shape: (16, 16)
# Tree ID: 30599, Optical Image Shape: (16, 16, 3)
# Tree ID: 30599, Sar Image Shape: (16, 16)
# Tree ID: 30600, Optical Image Shape: (16, 16, 3)
# Tree ID: 30600, Sar Image Shape: (16, 16)
# Tree ID: 30601, Optical Image Shape: (16, 16, 3)
# Tree ID: 30601, Sar Image Shape: (16, 16)
# Tree ID: 30602, Optical Image Shape: (16, 16, 3)
# Tree ID: 30602, Sar Image Shape: (16, 16)
# Tree ID: 30603, Optical Image Shape: (16, 16, 3)
# Tree ID: 30603, Sar Image Shape: (16, 16)
# Tree ID: 30604, Optical Image Shape: (16, 16, 3)
# Tree ID: 30604, Sar Image Shape: (16, 16)
# Tree ID: 30605, Optical Image Shape: (16, 16, 3)
# Tree ID: 30605, Sar Image Shape: (16, 16)
# Tree ID: 30606, Optical Image Shape: (16, 16, 3)
# Tree ID: 30606, Sar Image Shape: (16, 16)
# Tree ID: 30607, Optical Image Shape: (16, 16, 3)
# Tree ID: 30607, Sar Image Shape: (16, 16)
# Tree ID: 30608, Optical Image Shape: (16, 16, 3)
# Tree ID: 30608, Sar Image Shape: (16, 16)
# Tree ID: 30609, Optical Image Shape: (16, 16, 3)
# Tree ID: 30609, Sar Image Shape: (16, 16)
# Tree ID: 30610, Optical Image Shape: (16, 16, 3)
# Tree ID: 30610, Sar Image Shape: (16, 16)
# Tree ID: 30611, Optical Image Shape: (16, 16, 3)
# Tree ID: 30611, Sar Image Shape: (16, 16)
# Tree ID: 30612, Optical Image Shape: (16, 16, 3)
# Tree ID: 30612, Sar Image Shape: (16, 16)
# Tree ID: 30613, Optical Image Shape: (16, 16, 3)
# Tree ID: 30613, Sar Image Shape: (16, 16)
# Tree ID: 30614, Optical Image Shape: (16, 16, 3)
# Tree ID: 30614, Sar Image Shape: (16, 16)
# Tree ID: 30615, Optical Image Shape: (16, 16, 3)
# Tree ID: 30615, Sar Image Shape: (16, 16)
# Tree ID: 30616, Optical Image Shape: (16, 16, 3)
# Tree ID: 30616, Sar Image Shape: (16, 16)
# Tree ID: 30617, Optical Image Shape: (16, 16, 3)
# Tree ID: 30617, Sar Image Shape: (16, 16)
# Tree ID: 30618, Optical Image Shape: (16, 16, 3)
# Tree ID: 30618, Sar Image Shape: (16, 16)
# Tree ID: 30619, Optical Image Shape: (16, 16, 3)
# Tree ID: 30619, Sar Image Shape: (16, 16)
# Tree ID: 30620, Optical Image Shape: (16, 16, 3)
# Tree ID: 30620, Sar Image Shape: (16, 16)
# Tree ID: 30621, Optical Image Shape: (16, 16, 3)
# Tree ID: 30621, Sar Image Shape: (16, 16)
# Tree ID: 30622, Optical Image Shape: (16, 16, 3)
# Tree ID: 30622, Sar Image Shape: (16, 16)
# Tree ID: 30623, Optical Image Shape: (16, 16, 3)
# Tree ID: 30623, Sar Image Shape: (16, 16)
# Tree ID: 30624, Optical Image Shape: (16, 16, 3)
# Tree ID: 30624, Sar Image Shape: (16, 16)
# Tree ID: 30625, Optical Image Shape: (16, 16, 3)
# Tree ID: 30625, Sar Image Shape: (16, 16)
# Tree ID: 30626, Optical Image Shape: (16, 16, 3)
# Tree ID: 30626, Sar Image Shape: (16, 16)
# Tree ID: 30627, Optical Image Shape: (16, 16, 3)
# Tree ID: 30627, Sar Image Shape: (16, 16)
# Tree ID: 30628, Optical Image Shape: (16, 16, 3)
# Tree ID: 30628, Sar Image Shape: (16, 16)
# Tree ID: 30629, Optical Image Shape: (16, 16, 3)
# Tree ID: 30629, Sar Image Shape: (16, 16)
# Tree ID: 30630, Optical Image Shape: (16, 16, 3)
# Tree ID: 30630, Sar Image Shape: (16, 16)
# Tree ID: 30631, Optical Image Shape: (16, 16, 3)
# Tree ID: 30631, Sar Image Shape: (16, 16)
# Tree ID: 30632, Optical Image Shape: (16, 16, 3)
# Tree ID: 30632, Sar Image Shape: (16, 16)
# Tree ID: 30633, Optical Image Shape: (16, 16, 3)
# Tree ID: 30633, Sar Image Shape: (16, 16)
# Tree ID: 30634, Optical Image Shape: (16, 16, 3)
# Tree ID: 30634, Sar Image Shape: (16, 16)
# Tree ID: 30635, Optical Image Shape: (16, 16, 3)
# Tree ID: 30635, Sar Image Shape: (16, 16)
# Tree ID: 30636, Optical Image Shape: (16, 16, 3)
# Tree ID: 30636, Sar Image Shape: (16, 16)
# Tree ID: 30637, Optical Image Shape: (16, 16, 3)
# Tree ID: 30637, Sar Image Shape: (16, 16)
# Tree ID: 30638, Optical Image Shape: (16, 16, 3)
# Tree ID: 30638, Sar Image Shape: (16, 16)
# Tree ID: 30639, Optical Image Shape: (16, 16, 3)
# Tree ID: 30639, Sar Image Shape: (16, 16)
# Tree ID: 30640, Optical Image Shape: (16, 16, 3)
# Tree ID: 30640, Sar Image Shape: (16, 16)
# Tree ID: 30641, Optical Image Shape: (16, 16, 3)
# Tree ID: 30641, Sar Image Shape: (16, 16)
# Tree ID: 30642, Optical Image Shape: (16, 16, 3)
# Tree ID: 30642, Sar Image Shape: (16, 16)
# Tree ID: 30643, Optical Image Shape: (16, 16, 3)
# Tree ID: 30643, Sar Image Shape: (16, 16)
# Tree ID: 30644, Optical Image Shape: (16, 16, 3)
# Tree ID: 30644, Sar Image Shape: (16, 16)
# Tree ID: 30645, Optical Image Shape: (16, 16, 3)
# Tree ID: 30645, Sar Image Shape: (16, 16)
# Tree ID: 30646, Optical Image Shape: (16, 16, 3)
# Tree ID: 30646, Sar Image Shape: (16, 16)
# Tree ID: 30647, Optical Image Shape: (16, 16, 3)
# Tree ID: 30647, Sar Image Shape: (16, 16)
# Tree ID: 30648, Optical Image Shape: (16, 16, 3)
# Tree ID: 30648, Sar Image Shape: (16, 16)
# Tree ID: 30649, Optical Image Shape: (16, 16, 3)
# Tree ID: 30649, Sar Image Shape: (16, 16)
# Tree ID: 30650, Optical Image Shape: (16, 16, 3)
# Tree ID: 30650, Sar Image Shape: (16, 16)
# Tree ID: 30651, Optical Image Shape: (16, 16, 3)
# Tree ID: 30651, Sar Image Shape: (16, 16)
# Tree ID: 30652, Optical Image Shape: (16, 16, 3)
# Tree ID: 30652, Sar Image Shape: (16, 16)
# Tree ID: 30653, Optical Image Shape: (16, 16, 3)
# Tree ID: 30653, Sar Image Shape: (16, 16)
# Tree ID: 30654, Optical Image Shape: (16, 16, 3)
# Tree ID: 30654, Sar Image Shape: (16, 16)
# Tree ID: 30655, Optical Image Shape: (16, 16, 3)
# Tree ID: 30655, Sar Image Shape: (16, 16)
# Tree ID: 30656, Optical Image Shape: (16, 16, 3)
# Tree ID: 30656, Sar Image Shape: (16, 16)
# Tree ID: 30657, Optical Image Shape: (16, 16, 3)
# Tree ID: 30657, Sar Image Shape: (16, 16)
# Tree ID: 30658, Optical Image Shape: (16, 16, 3)
# Tree ID: 30658, Sar Image Shape: (16, 16)
# Tree ID: 30659, Optical Image Shape: (16, 16, 3)
# Tree ID: 30659, Sar Image Shape: (16, 16)
# Tree ID: 30660, Optical Image Shape: (16, 16, 3)
# Tree ID: 30660, Sar Image Shape: (16, 16)
# Tree ID: 30661, Optical Image Shape: (16, 16, 3)
# Tree ID: 30661, Sar Image Shape: (16, 16)
# Tree ID: 30662, Optical Image Shape: (16, 16, 3)
# Tree ID: 30662, Sar Image Shape: (16, 16)
# Tree ID: 30663, Optical Image Shape: (16, 16, 3)
# Tree ID: 30663, Sar Image Shape: (16, 16)
# Tree ID: 30664, Optical Image Shape: (16, 16, 3)
# Tree ID: 30664, Sar Image Shape: (16, 16)
# Tree ID: 30665, Optical Image Shape: (16, 16, 3)
# Tree ID: 30665, Sar Image Shape: (16, 16)
# Tree ID: 30666, Optical Image Shape: (16, 16, 3)
# Tree ID: 30666, Sar Image Shape: (16, 16)
# Tree ID: 30667, Optical Image Shape: (16, 16, 3)
# Tree ID: 30667, Sar Image Shape: (16, 16)
# Tree ID: 30668, Optical Image Shape: (16, 16, 3)
# Tree ID: 30668, Sar Image Shape: (16, 16)
# Tree ID: 30669, Optical Image Shape: (16, 16, 3)
# Tree ID: 30669, Sar Image Shape: (16, 16)
# Tree ID: 30670, Optical Image Shape: (16, 16, 3)
# Tree ID: 30670, Sar Image Shape: (16, 16)
# Tree ID: 30671, Optical Image Shape: (16, 16, 3)
# Tree ID: 30671, Sar Image Shape: (16, 16)
# Tree ID: 30672, Optical Image Shape: (16, 16, 3)
# Tree ID: 30672, Sar Image Shape: (16, 16)
# Tree ID: 30673, Optical Image Shape: (16, 16, 3)
# Tree ID: 30673, Sar Image Shape: (16, 16)
# Tree ID: 30674, Optical Image Shape: (16, 16, 3)
# Tree ID: 30674, Sar Image Shape: (16, 16)
# Tree ID: 30675, Optical Image Shape: (16, 16, 3)
# Tree ID: 30675, Sar Image Shape: (16, 16)
# Tree ID: 30676, Optical Image Shape: (16, 16, 3)
# Tree ID: 30676, Sar Image Shape: (16, 16)
# Tree ID: 30677, Optical Image Shape: (16, 16, 3)
# Tree ID: 30677, Sar Image Shape: (16, 16)
# Tree ID: 30678, Optical Image Shape: (16, 16, 3)
# Tree ID: 30678, Sar Image Shape: (16, 16)
# Tree ID: 30679, Optical Image Shape: (16, 16, 3)
# Tree ID: 30679, Sar Image Shape: (16, 16)
# Tree ID: 30680, Optical Image Shape: (16, 16, 3)
# Tree ID: 30680, Sar Image Shape: (16, 16)
# Tree ID: 30681, Optical Image Shape: (16, 16, 3)
# Tree ID: 30681, Sar Image Shape: (16, 16)
# Tree ID: 30682, Optical Image Shape: (16, 16, 3)
# Tree ID: 30682, Sar Image Shape: (16, 16)
# Tree ID: 30683, Optical Image Shape: (16, 16, 3)
# Tree ID: 30683, Sar Image Shape: (16, 16)
# Tree ID: 30684, Optical Image Shape: (16, 16, 3)
# Tree ID: 30684, Sar Image Shape: (16, 16)
# Tree ID: 30685, Optical Image Shape: (16, 16, 3)
# Tree ID: 30685, Sar Image Shape: (16, 16)
# Tree ID: 30686, Optical Image Shape: (16, 16, 3)
# Tree ID: 30686, Sar Image Shape: (16, 16)

# %%
# Convert lists to numpy arrays
optical_images1 = np.array(optical_image_paths)
sar_images1 = np.array(sar_image_paths)
labels = np.array(labels)
species_labels = np.array(species_labels)
height_labels = np.array(height_labels)

# Print the shapes of the arrays
print("Optical Image Shape:", optical_images1.shape)
print("SAR Image Shape:", sar_images1.shape)
print("Labels Shape:", labels.shape)
print("Species Labels Shape:", species_labels.shape)
print("Height Labels Shape:", height_labels.shape)
# Out:
# Optical Image Shape: (29860, 16, 16, 3)
# SAR Image Shape: (29860, 16, 16)
# Labels Shape: (29860,)
# Species Labels Shape: (29860,)
# Height Labels Shape: (29860,)

# %%
# Reshape SAR images to (16, 16, 1)
sar_images1 = sar_images1[..., np.newaxis]

# %%
# Print the shapes of the arrays
print("Optical Image Shape:", optical_images1.shape)
print("SAR Image Shape:", sar_images1.shape)
print("Labels Shape:", labels.shape)
print("Species Labels Shape:", species_labels.shape)
# Out:
# Optical Image Shape: (29860, 16, 16, 3)
# SAR Image Shape: (29860, 16, 16, 1)
# Labels Shape: (29860,)
# Species Labels Shape: (29860,)

# %%
plt.imshow(optical_images1[7994])

# %%
plt.imshow(sar_images1[7994])

# %%
import matplotlib.pyplot as plt

# Assuming optical_images1 and sar_images1 are your image arrays
image_id = 7994

# Create a figure for displaying the images
plt.figure(figsize=(10, 5))

# Display optical image
plt.subplot(1, 2, 1)
plt.imshow(optical_images1[image_id])
plt.title(f'Optical Image ')
plt.axis('off')
plt.xlabel("Optical Image")

# Display corresponding SAR image
plt.subplot(1, 2, 2)
plt.imshow(sar_images1[image_id].squeeze())  # Use squeeze for SAR images if they have a singleton dimension
plt.title(f'SAR Image')
plt.axis('off')
plt.xlabel("SAR Image")

plt.tight_layout()
plt.show()

# %%
# Split the data into training and testing sets
train_optical, test_optical, train_sar, test_sar, train_labels, test_labels, train_species, test_species = train_test_split(
    optical_images1, sar_images1, labels, species_labels, test_size=0.35, random_state=42
)

# %% [markdown]
# # MultiDense Model for Multimodal Neural Network
#
# ## Model Description
#
# The **MultiDense Model** belongs to the multimodal neural network class, specifically designed for tasks that involve processing information from multiple modalities. This model utilizes a series of dense layers to capture and integrate features from diverse input sources.
#
# ### Layers
#
# 1. **SAR Dense (`dense_sar`):**
#    - Type: Dense
#    - Output Shape: (None, sar_features)
#    - Description: Processes SAR data through a dense layer.
#
# 2. **Optical Dense (`dense_optical`):**
#    - Type: Dense
#    - Output Shape: (None, optical_features)
#    - Description: Processes Optical data through a dense layer.
#
# 3. **Additional Input Dense (`dense_additional`):**
#    - Type: Dense
#    - Output Shape: (None, additional_features)
#    - Description: Processes any supplementary input through a dense layer.
#
# 4. **Concatenation (`concatenate`):**
#    - Output Shape: (None, total_features)
#    - Description: Concatenates the outputs from the dense layers.
#
# 5. **Output Dense (`dense_output`):**
#    - Type: Dense
#    - Output Shape: (None, 1)
#    - Description: Produces the final output.
#
# ### Model Parameters
#
# - **Total Parameters:** 453825
#
# ### Purpose
#
# The **MultiDense Model** is tailored to handle multimodal tasks by effectively learning and combining information from SAR, Optical, and additional inputs. The architecture leverages dense layers to facilitate feature extraction and integration, making it suitable for various applications, such as height estimation.

# %% [markdown]
# ## Mean Square Error

# %%
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.preprocessing import StandardScaler

# Assuming train_labels and test_labels are the target variables
#scaler = StandardScaler()
#train_labels_scaled = scaler.fit_transform(train_labels.reshape(-1, 1)).flatten()
#test_labels_scaled = scaler.transform(test_labels.reshape(-1, 1)).flatten()

# Define the processing layers for each input
optical_input = layers.Input(shape=(16, 16, 3))
sar_input = layers.Input(shape=(16, 16, 1))
species_input = layers.Input(shape=(1,))

# Processing layers for optical input
optical_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(optical_input)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(optical_output)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Flatten()(optical_output)

# Processing layers for SAR input
sar_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(sar_input)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(sar_output)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Flatten()(sar_output)

# Processing layers for species input
species_output = layers.Dense(32, activation="relu")(species_input)

# Concatenate the flattened outputs
merged = layers.concatenate([optical_output, sar_output, species_output])

# Additional dense layers
dense_layer1 = layers.Dense(256, activation="relu")(merged)
dense_layer2 = layers.Dense(128, activation="relu")(dense_layer1)

# Define the output layer
output_layer = layers.Dense(1, activation="linear", name="biomass_output")(dense_layer2)

# Create the model
model = keras.Model(inputs=[optical_input, sar_input, species_input], outputs=output_layer, name="custom_model")

from tensorflow.keras import backend as K

def r_squared(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - SS_res / (SS_tot + K.epsilon())



# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=0.001) 
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='huber_loss', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', r_squared])
# Print the summary of the model
model.summary()
#early stopping 
early_stopping = EarlyStopping(
    monitor='val_loss',  # you can use 'val_mae' if you prefer to monitor mean absolute error
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# Train the model
# Train the model with early stopping and validation data

history=model.fit([train_optical, train_sar, train_species], train_labels, epochs=100, batch_size=16, validation_split=0.2, callbacks=[early_stopping] )

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_sar, test_species], test_labels)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# Model: "custom_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 16, 16, 3)]          0         []
#
#  input_2 (InputLayer)        [(None, 16, 16, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 64)           1792      ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)           640       ['input_2[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 7, 7, 64)             0         ['conv2d[0][0]']
#  D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 7, 7, 64)             0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 128)            73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 128)            73856     ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 2, 2, 128)            0         ['conv2d_1[0][0]']
#  g2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)            0         ['conv2d_3[0][0]']
#  g2D)
#
#  input_3 (InputLayer)        [(None, 1)]                  0         []
#
#  flatten (Flatten)           (None, 512)                  0         ['max_pooling2d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 512)                  0         ['max_pooling2d_3[0][0]']
#
#  dense (Dense)               (None, 32)                   64        ['input_3[0][0]']
#
#  concatenate (Concatenate)   (None, 1056)                 0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]',
#                                                                      'dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  270592    ['concatenate[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  32896     ['dense_1[0][0]']
#
#  biomass_output (Dense)      (None, 1)                    129       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 453825 (1.73 MB)
# Trainable params: 453825 (1.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 971/971 [==============================] - 14s 13ms/step - loss: 44.5298 - mae: 2.2011 - val_loss: 4.2343 - val_mae: 1.7224
# Epoch 2/100
# 971/971 [==============================] - 11s 12ms/step - loss: 3.7101 - mae: 1.5763 - val_loss: 3.3375 - val_mae: 1.5087
# Epoch 3/100
# 971/971 [==============================] - 12s 13ms/step - loss: 3.3203 - mae: 1.4781 - val_loss: 3.1317 - val_mae: 1.4562
# Epoch 4/100
# 971/971 [==============================] - 12s 13ms/step - loss: 3.0327 - mae: 1.4033 - val_loss: 2.9306 - val_mae: 1.3990
# Epoch 5/100
# 971/971 [==============================] - 12s 12ms/step - loss: 2.8937 - mae: 1.3693 - val_loss: 2.8886 - val_mae: 1.3504
# Epoch 6/100
# 971/971 [==============================] - 12s 12ms/step - loss: 2.8238 - mae: 1.3480 - val_loss: 2.7977 - val_mae: 1.3471
# Epoch 7/100
# 971/971 [==============================] - 12s 12ms/step - loss: 2.7392 - mae: 1.3233 - val_loss: 2.8541 - val_mae: 1.3463
# Epoch 8/100
# 971/971 [==============================] - 12s 12ms/step - loss: 2.6792 - mae: 1.3083 - val_loss: 3.1051 - val_mae: 1.4475
# Epoch 9/100
# 971/971 [==============================] - 11s 12ms/step - loss: 2.6616 - mae: 1.3054 - val_loss: 2.8676 - val_mae: 1.3566
# 327/327 [==============================] - 2s 7ms/step - loss: 2.8047 - mae: 1.3452
# Test Loss: 2.804731607437134, Test MAE: 1.3451664447784424

# %%
# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])
#predictions_original = scaler.inverse_transform(predictions)
# Plot actual vs predicted values
plt.scatter(test_labels, predictions)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')

# Print actual and predicted values
#for actual, predicted in zip(test_labels, predictions_original):
#    print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()
# Out:
# 327/327 [==============================] - 3s 7ms/step

# %%
import numpy as np

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(test_labels.flatten(), predictions.flatten())[0, 1]
print("Correlation Coefficient:", correlation_coefficient)
# Out:
# Correlation Coefficient: 0.47227511264144917

# %%
import numpy as np

# Assuming predictions is the array containing the estimated biomass values
predictions = model.predict([test_optical, test_sar, test_species])

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(test_labels.flatten(), predictions.flatten())[0, 1]

print("Correlation Coefficient:", correlation_coefficient)
# Out:
# 327/327 [==============================] - 2s 7ms/step
# Correlation Coefficient: 0.47227511264144917

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])


# Plot actual vs predicted values
plt.scatter(test_labels, predictions)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')


# Print actual and predicted values
for actual, predicted in zip(test_labels, predictions):
    print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()

# %%
log_predictions = model.predict([test_optical, test_sar, test_species])
predictions = np.expm1(log_predictions)  # Inverse of log1p is expm1


# Assuming that the test set index corresponds to the Tree ID
results = pd.DataFrame({
    'ActualBiomass': np.expm1(test_labels),  # Need to inverse the log transformation of y_test
    'PredictedBiomass': predictions.flatten()
})
print(results)

# %%
import time
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions using the model
predictions = model.predict([test_optical, test_sar, test_species])

# The number of epochs the model actually trained
epochs_trained = len(history.history['loss'])
# Evaluate regression metrics
mae = mean_absolute_error(test_labels, predictions)
rmse = mean_squared_error(test_labels, predictions, squared=False)


# Print the results
#print(f"Computational Time: {computational_time} seconds")
print(f"Number of Epochs Trained: {epochs_trained}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")

# %%
from sklearn.metrics import r2_score

# Calculate R-squared
r_squared_value = r2_score(test_labels, predictions)
print("R-squared Value:", r_squared_value)
# Out:
# R-squared Value: 0.21755537374293987

# %%
import numpy as np

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(test_labels, test_predictions)[0, 1]
print("Correlation Coefficient:", correlation_coefficient)

# %% [markdown]
# ## Huber loss

# %%
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.preprocessing import StandardScaler

# Assuming train_labels and test_labels are the target variables
scaler = StandardScaler()
train_labels_scaled = scaler.fit_transform(train_labels.reshape(-1, 1)).flatten()
test_labels_scaled = scaler.transform(test_labels.reshape(-1, 1)).flatten()

# Define the processing layers for each input
optical_input = layers.Input(shape=(16, 16, 3))
sar_input = layers.Input(shape=(16, 16, 1))
species_input = layers.Input(shape=(1,))

# Processing layers for optical input
optical_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(optical_input)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(optical_output)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Flatten()(optical_output)

# Processing layers for SAR input
sar_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(sar_input)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(sar_output)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Flatten()(sar_output)

# Processing layers for species input
species_output = layers.Dense(32, activation="relu")(species_input)

# Concatenate the flattened outputs
merged = layers.concatenate([optical_output, sar_output, species_output])

# Additional dense layers
dense_layer1 = layers.Dense(256, activation="relu")(merged)
dense_layer2 = layers.Dense(128, activation="relu")(dense_layer1)

# Define the output layer
output_layer = layers.Dense(1, activation="linear", name="biomass_output")(dense_layer2)

# Create the model
model = keras.Model(inputs=[optical_input, sar_input, species_input], outputs=output_layer, name="custom_model")

from tensorflow.keras import backend as K

def r_squared(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - SS_res / (SS_tot + K.epsilon())



# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=0.001) 
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])
model.compile(optimizer=optimizer, loss='huber_loss', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', r_squared])
# Print the summary of the model
model.summary()
#early stopping 
early_stopping = EarlyStopping(
    monitor='val_loss',  # you can use 'val_mae' if you prefer to monitor mean absolute error
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# Train the model
# Train the model with early stopping and validation data

history=model.fit([train_optical, train_sar, train_species], train_labels_scaled, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping] )

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_sar, test_species], test_labels_scaled)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])
predictions_original = scaler.inverse_transform(predictions)
# Plot actual vs predicted values
plt.scatter(test_labels, predictions_original)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')

# Print actual and predicted values
#for actual, predicted in zip(test_labels, predictions_original):
    #print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()

# %% [markdown]
# ## Mean Squared Logarithmic Error

# %%
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.preprocessing import StandardScaler

# Assuming train_labels and test_labels are the target variables
#scaler = StandardScaler()
#train_labels_scaled = scaler.fit_transform(train_labels.reshape(-1, 1)).flatten()
#test_labels_scaled = scaler.transform(test_labels.reshape(-1, 1)).flatten()

# Define the processing layers for each input
optical_input = layers.Input(shape=(16, 16, 3))
sar_input = layers.Input(shape=(16, 16, 1))
species_input = layers.Input(shape=(1,))

# Processing layers for optical input
optical_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(optical_input)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(optical_output)
optical_output = layers.MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = layers.Flatten()(optical_output)

# Processing layers for SAR input
sar_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(sar_input)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Conv2D(128, kernel_size=(3, 3), activation="relu")(sar_output)
sar_output = layers.MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = layers.Flatten()(sar_output)

# Processing layers for species input
species_output = layers.Dense(32, activation="relu")(species_input)

# Concatenate the flattened outputs
merged = layers.concatenate([optical_output, sar_output, species_output])

# Additional dense layers
dense_layer1 = layers.Dense(256, activation="relu")(merged)
dense_layer2 = layers.Dense(128, activation="relu")(dense_layer1)

# Define the output layer
output_layer = layers.Dense(1, activation="ELU", name="biomass_output")(dense_layer2)

# Create the model
model = keras.Model(inputs=[optical_input, sar_input, species_input], outputs=output_layer, name="custom_model")

from tensorflow.keras import backend as K

def r_squared(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - SS_res / (SS_tot + K.epsilon())



# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=0.001) 
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='huber_loss', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', r_squared])
# Print the summary of the model
model.summary()
#early stopping 
early_stopping = EarlyStopping(
    monitor='val_loss',  # you can use 'val_mae' if you prefer to monitor mean absolute error
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# Train the model
# Train the model with early stopping and validation data

history=model.fit([train_optical, train_sar, train_species], train_labels, epochs=100, batch_size=16, validation_split=0.2, callbacks=[early_stopping] )

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_sar, test_species], test_labels)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])
#predictions_original = scaler.inverse_transform(predictions)
# Plot actual vs predicted values
plt.scatter(test_labels, predictions)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')

# Print actual and predicted values
for actual, predicted in zip(test_labels, predictions):
    print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])

# Plot actual vs predicted values
plt.scatter(test_labels, predictions)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')

# Print actual and predicted values
#for actual, predicted in zip(test_labels, predictions):
#    print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()

# %%
log_predictions = model.predict([test_optical, test_sar, test_species])
predictions = np.expm1(log_predictions)  # Inverse of log1p is expm1


# Assuming that the test set index corresponds to the Tree ID
results = pd.DataFrame({
    'ActualBiomass': np.expm1(test_labels),  # Need to inverse the log transformation of y_test
    'PredictedBiomass': predictions.flatten()
})
print(results)

# %%
import time
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions using the model
predictions = model.predict([test_optical, test_sar, test_species])

# The number of epochs the model actually trained
epochs_trained = len(history.history['loss'])
# Evaluate regression metrics
mae = mean_absolute_error(test_labels, predictions)
rmse = mean_squared_error(test_labels, predictions, squared=False)


# Print the results
#print(f"Computational Time: {computational_time} seconds")
print(f"Number of Epochs Trained: {epochs_trained}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")

# %% [markdown]
# # RESNET50
#
# ## ResNet-Based Biomass Estimation Model
#
# The ResNet-Based Biomass Estimation Model is designed to predict biomass values from optical images, utilizing the ResNet50 architecture as a feature extractor. The model also incorporates categorical information about tree species to enhance its predictive capabilities.
#
# ### Model Architecture
#
# The model comprises the following components:
#
# - **Optical Input**: Image data from optical sources, preprocessed to extract specific channels (2, 3, and 5) and resized to (32, 32, 3).
#
# #### ResNet50 Feature Extractor
#
# The core of the model is a ResNet50 feature extractor, pre-trained on ImageNet. The ResNet layers are set to be non-trainable to leverage the learned representations.
#
# #### Additional Dense Layers
#
# Following the ResNet feature extraction, two dense layers with ReLU activation and dropout are added to capture complex relationships in the data.
#
# #### Concatenation and Output Layer
#
# The outputs from the ResNet feature extraction and additional dense layers are concatenated. The final output layer predicts the biomass value using linear activation.
#
# ### Model Training
#
# The model is trained using mean squared error as the loss function and mean absolute error as the evaluation metric. The Adam optimizer is employed with a learning rate of 0.001.
#
# ### Training History
#
# The model is trained for 10 epochs on the training data, with a batch size of 32. The training progress is stored in the `history` variable.
#
# ### Model Evaluation
#
# After training, the model is evaluated on the test set, and the test loss and mean absolute error are printed.

# %%
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
# Create lists for image paths, labels, and species labels
optical_image_paths = []
sar_image_paths = []

# Iterate through tree IDs
for tree_id in tree_data['treeID']:
    # Construct paths for optical and SAR images
    optical_path = os.path.join(optical_folder, f"tree_{tree_id}.0.tif")
    sar_path = os.path.join(sar_folder, f"tree_{tree_id}.0.tif")

    try:
        # Load optical image and extract specific channels (2, 3, and 5)
        optical_image = tifffile.imread(optical_path)[:, :, [2, 3, 5]]
        sar_image = tifffile.imread(sar_path)

        # Resize optical image to (32, 32, 3)
        resized_optical_image = array_to_img(optical_image).resize((32, 32))
        resized_optical_image = img_to_array(resized_optical_image)
        
        # Save SAR and resized optical images to lists
        sar_image_paths.append(sar_image)
        optical_image_paths.append(resized_optical_image)
    except Exception as e:
        print(f"Error loading optical image {optical_path}: {e}")

# Convert lists to numpy arrays
optical_images1 = np.array(optical_image_paths)
sar_images1 = np.array(sar_image_paths)
labels = np.array(labels)
species_labels = np.array(species_labels)
height_labels = np.array(height_labels)

# %%
# Reshape SAR images to (16, 16, 1)
sar_images1 = sar_images1[..., np.newaxis]

# Print the shapes of the arrays
print("Optical Image Shape:", optical_images1.shape)
print("SAR Image Shape:", sar_images1.shape)
print("Labels Shape:", labels.shape)
print("Species Labels Shape:", species_labels.shape)
print("Height Labels Shape:", height_labels.shape) 


# Split the data into training and testing sets
train_optical, test_optical, train_sar, test_sar, train_labels, test_labels, train_species, test_species = train_test_split(
    optical_images1, sar_images1, labels, species_labels, test_size=0.35, random_state=42
)

# %%
from tensorflow.keras.applications import ResNet50
from sklearn.preprocessing import StandardScaler

# Assuming train_labels and test_labels are the target variables
scaler = StandardScaler()
train_labels_scaled = scaler.fit_transform(train_labels.reshape(-1, 1)).flatten()
test_labels_scaled = scaler.transform(test_labels.reshape(-1, 1)).flatten()

# Define the processing layers for each input
optical_input = layers.Input(shape=(32, 32, 3))
sar_input = layers.Input(shape=(16, 16, 1))
species_input = layers.Input(shape=(1,))

# Load the ResNet50 model pre-trained on ImageNet data
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Set the ResNet layers to be non-trainable
for layer in resnet_model.layers:
    layer.trainable = False

# Get the output of the ResNet50 model
resnet_output = resnet_model.output

# Flatten the output
resnet_flatten = layers.Flatten()(resnet_output)


# Adding layers as needed
dense_layer1 = layers.Dense(256, activation="relu")(resnet_flatten)
dropout1 = layers.Dropout(0.5)(dense_layer1)

dense_layer2 = layers.Dense(128, activation="relu")(dropout1)
dropout2 = layers.Dropout(0.5)(dense_layer2)



# Concatenate the flattened output with the species input
merged = layers.concatenate([resnet_flatten, species_input])

# Define the output layer
output_layer = layers.Dense(1, activation="linear", name="biomass_output")(merged)


# Create the model
model = keras.Model(inputs=[resnet_model.input, species_input], outputs=output_layer)

optimizer = keras.optimizers.Adam(learning_rate=0.001) 
# Compile the model
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='huber_loss', metrics=['mae'])
# Print the summary of the model
model.summary()
#early stopping 
early_stopping = EarlyStopping(
    monitor='val_loss',  # you can use 'val_mae' if you prefer to monitor mean absolute error
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# Train the model with early stopping and validation data


# Train the model
history=model.fit([train_optical, train_species], train_labels_scaled, epochs=100, batch_size=32, validation_split=0.2 ,  callbacks=[early_stopping] )

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_species], test_labels_scaled)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
predictions = model.predict([test_optical, test_species])
predictions_original = scaler.inverse_transform(predictions)
# Assuming you have a test dataset and model.predict() is used to get predictions
#predictions = model.predict([test_optical, test_sar, test_species])

# Plot actual vs predicted values
plt.scatter(test_labels_scaled, predictions)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')
plt.show()

# %% [markdown]
# # Transformer-Based Multimodal Biomass Estimation Model
#
# ## Model Description:
#
# The **Transformer-Based Multimodal Biomass Estimation Model** (referred to as "model_1") is an advanced architecture designed for accurate biomass estimation in a biomimicry application. This model integrates species information, SAR (Synthetic Aperture Radar) data, and Optical data using a transformer-like structure, incorporating attention mechanisms for effective feature extraction.
#
# ### Input Layers
#
# 1. **Species Input (`species_input`):**
#    - Shape: (None, 1)
#    - Description: Represents categorical species information.
#
# 2. **Optical Input (`optical_input`):**
#    - Shape: (None, 16, 16, 3)
#    - Description: Represents optical data.
#
# 3. **SAR Input (`sar_input`):**
#    - Shape: (None, 16, 16, 1)
#    - Description: Represents SAR data.
#
# ### Transformer Blocks
#
# 1. **Embedding Layer (`embedding`):**
#    - Output Shape: (None, 1, 16)
#    - Description: Embeds species information.
#
# 2. **Layer Normalization (`layer_normalization`):**
#    - Output Shape: (None, 1, 16)
#    - Description: Normalizes embedded species information.
#
# 3. **Multi-Head Attention (`multi_head_attention`):**
#    - Output Shape: (None, 1, 16)
#    - Description: Applies multi-head attention to the normalized species information.
#
# 4. **Dropout Layer (`dropout`):**
#    - Output Shape: (None, 1, 16)
#    - Description: Introduces dropout for regularization.
#
# 5. **Convolutional Layers (`conv2d_2`, `conv2d_4`):**
#    - Output Shape: (None, 14, 14, 64)
#    - Description: Applies convolution to optical and SAR data.
#
# 6. **Pooling and Dense Layers:**
#    - Various pooling and dense layers for feature extraction and dimensionality reduction.
#
# 7. **Concatenation (`concatenate_1`):**
#    - Output Shape: (None, 144)
#    - Description: Concatenates outputs from the transformer and convolutional layers.
#
# 8. **Dense Layers (`dense_5`):**
#    - Output Shape: (None, 128)
#    - Description: Processes the concatenated data.
#
# ### Output Layer
#
# - **Biomass Output (`biomass_output`):**
#   - Type: Dense
#   - Output Shape: (None, 1)
#   - Description: Produces the final output for biomass estimation.
#
# ### Model Parameters
#
# - **Total Parameters:** 236,257
# - **Trainable Parameters:** 236,257
# - **Non-trainable Parameters:** 0
#
# ### Model Purpose
#
# The **Transformer-Based Multimodal Biomass Estimation Model** leverages a transformer-like structure for effective feature extraction from species information, SAR, and Optical data. The model is tailored for biomimicry applications, providing accurate biomass estimation by capturing both spatial and contextual information.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, MultiHeadAttention, LayerNormalization, concatenate
from sklearn.preprocessing import StandardScaler

# Assuming train_labels and test_labels are the target variables
scaler = StandardScaler()
train_labels_scaled = scaler.fit_transform(train_labels.reshape(-1, 1)).flatten()
test_labels_scaled = scaler.transform(test_labels.reshape(-1, 1)).flatten()


def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    x = LayerNormalization(epsilon=1e-6)(inputs)
    attention = MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(x, x)
    attention = Dropout(dropout)(attention)
    res = x + attention

    x = LayerNormalization(epsilon=1e-6)(res)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    x = Dense(inputs.shape[-1])(x)
    return res + x

# Define processing layers for each input
optical_input = Input(shape=(16, 16, 3), name="optical_input")
sar_input = Input(shape=(16, 16, 1), name="sar_input")
species_input = Input(shape=(1,), name="species_input")

# Processing layers for optical input
optical_output = Conv2D(64, kernel_size=(3, 3), activation="relu")(optical_input)
optical_output = MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = Conv2D(128, kernel_size=(3, 3), activation="relu")(optical_output)
optical_output = MaxPooling2D(pool_size=(2, 2))(optical_output)
optical_output = Flatten()(optical_output)
optical_output = Dense(64, activation="relu")(optical_output)

# Processing layers for SAR input
sar_output = Conv2D(64, kernel_size=(3, 3), activation="relu")(sar_input)
sar_output = MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = Conv2D(128, kernel_size=(3, 3), activation="relu")(sar_output)
sar_output = MaxPooling2D(pool_size=(2, 2))(sar_output)
sar_output = Flatten()(sar_output)
sar_output = Dense(64, activation="relu")(sar_output)

# Processing layers for species input using transformer
species_output = layers.Embedding(input_dim=4, output_dim=16, input_length=1)(species_input)
species_output = transformer_block(species_output, head_size=8, num_heads=2, ff_dim=16, dropout=0.1)
species_output = Flatten()(species_output)

# Concatenate the processed outputs
merged = concatenate([optical_output, sar_output, species_output])

# Additional dense layers if needed
merged = Dense(128, activation="relu")(merged)

# Output layer
output_layer = Dense(1, activation="linear", name="biomass_output")(merged)

# Create the model
model = models.Model(inputs=[optical_input, sar_input, species_input], outputs=output_layer)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])

#model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mae'])
model.compile(optimizer=optimizer, loss='huber_loss', metrics=['mae'])
# Print the summary of the model
model.summary()

# %%
# Assuming you have train_optical, train_sar, train_species, train_labels,
# test_optical, test_sar, test_species, and test_labels available
early_stopping = EarlyStopping(
    monitor='val_loss',  # you can use 'val_mae' if you prefer to monitor mean absolute error
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)
# Train the model
history=model.fit(
    [train_optical, train_sar, train_species],
    train_labels_scaled,
    epochs=100,
    batch_size=16,
    validation_split=0.3,
    callbacks=[early_stopping]
)

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_sar, test_species], test_labels_scaled)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
import matplotlib.pyplot as plt
predictions = model.predict([test_optical, test_sar, test_species])
predictions_original = scaler.inverse_transform(predictions)
# Assuming you have a test dataset and model.predict() is used to get predictions
#predictions = model.predict([test_optical, test_sar, test_species])

# Plot actual vs predicted values
plt.scatter(test_labels, predictions_original)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')
plt.show()

# %%
# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])
predictions_original = scaler.inverse_transform(predictions)
actual_ = []
predicted_ = []
# Print actual and predicted values only if they are close
for actual, predicted in zip(test_labels, predictions_original):
    if abs(actual - predicted[0]) < threshold:
        print(f"Actual: {actual:.2f}, Predicted: {predicted[0]:.2f}")
        actual_.append( actual)
        predicted_.append(predicted[0])
        
# Print actual and predicted values
for actual, predicted in zip(actual_, predicted_):
    print(f"Actual: {actual}, Predicted: {predicted}")

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Assuming you have a test dataset and model.predict() is used to get predictions

predictions = model.predict([test_optical, test_sar, test_species])
predictions_original = scaler.inverse_transform(predictions)

# Set a threshold for closeness
threshold = 30.0  # Adjust as needed

# Plot actual vs predicted values
plt.scatter(test_labels, predictions_original)
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.title('Actual vs Predicted Biomass')

# Print actual and predicted values only if they are close
for actual, predicted in zip(test_labels, predictions_original):
    if abs(actual - predicted[0]) < threshold:
        print(f"Actual: {actual:.2f}, Predicted: {predicted[0]:.2f}")

plt.show()

# %%
######################only Optical and SAR


from tensorflow import keras
from tensorflow.keras import layers

# Define the processing layers for each input
optical_input = layers.Input(shape=(16, 16, 3))
sar_input = layers.Input(shape=(16, 16, 1))

# Processing layers for optical input
optical_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(optical_input)
optical_output = layers.Flatten()(optical_output)
optical_output = layers.Dense(32, activation="relu")(optical_output)

# Processing layers for SAR input
sar_output = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(sar_input)
sar_output = layers.Flatten()(sar_output)
sar_output = layers.Dense(32, activation="relu")(sar_output)

# Concatenate the processed outputs
merged = layers.concatenate([optical_output, sar_output])

# Additional layers if needed
merged = layers.Dense(64, activation="relu")(merged)

# Output layer
output_layer = layers.Dense(1, activation="linear", name="biomass_output")(merged)

# Create the model
model = keras.Model(inputs=[optical_input, sar_input], outputs=output_layer)

# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

# Print the summary of the model
model.summary()

# Train the model
model.fit([train_optical, train_sar], train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate([test_optical, test_sar], test_labels)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
import matplotlib.pyplot as plt

# Make predictions using the model
log_predictions = model.predict([test_optical, test_sar, test_species])
predictions = np.expm1(log_predictions)  # Apply the inverse transformation

# Create a DataFrame for plotting
results = pd.DataFrame({
    'ActualBiomass': np.expm1(test_labels),  # Inverse the log transformation of test_labels
    'PredictedBiomass': predictions.flatten()
})

# Plot the results
plt.figure(figsize=(10, 8))
plt.scatter(results['ActualBiomass'], results['PredictedBiomass'], alpha=0.5)
plt.title('Actual vs Predicted Biomass')
plt.xlabel('Actual Biomass')
plt.ylabel('Predicted Biomass')
plt.plot([results['ActualBiomass'].min(), results['ActualBiomass'].max()], 
         [results['ActualBiomass'].min(), results['ActualBiomass'].max()], 'k--') # Ideal 1:1 line
plt.show()
